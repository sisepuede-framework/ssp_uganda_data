# %%
import pandas as pd
import os

# %%
SCRIPT_DIR_PATH = os.getcwd()
PARENT_DIR_PATH = os.path.dirname(SCRIPT_DIR_PATH)
TABLEAU_OUTPUT_DIR = os.path.join(PARENT_DIR_PATH, 'Tableau', 'data')

# %%
df_period_5 = pd.read_csv(os.path.join(TABLEAU_OUTPUT_DIR, 'uganda_rescaled_2025-08-20T13;21;41.290976_combined_2020_ref.csv'))
df_period_5
# Out:
#       strategy_id  primary_id                       Edgar_Class   CSC.Sector  \
# 0             0.0         0.0                    AG - Crops:CH4  Agriculture
# 1             0.0         0.0                    AG - Crops:CH4  Agriculture
# 2             0.0         0.0                    AG - Crops:CH4  Agriculture
# 3             0.0         0.0                    AG - Crops:CH4  Agriculture
# 4             0.0         0.0                    AG - Crops:CH4  Agriculture
# ...           ...         ...                               ...          ...
# 6888          NaN         NaN  Waste - Wastewater Treatment:N2O        Waste
# 6889          NaN         NaN  Waste - Wastewater Treatment:N2O        Waste
# 6890          NaN         NaN  Waste - Wastewater Treatment:N2O        Waste
# 6891          NaN         NaN  Waste - Wastewater Treatment:N2O        Waste
# 6892          NaN         NaN  Waste - Wastewater Treatment:N2O        Waste
#
# ...

# %%
df_period_7 = pd.read_csv(os.path.join(TABLEAU_OUTPUT_DIR, 'uganda_rescaled_2025-08-20T13;21;41.290976_combined_2022_ref.csv'))
df_period_7
# Out:
#       strategy_id  primary_id                       Edgar_Class   CSC.Sector  \
# 0             0.0         0.0                    AG - Crops:CH4  Agriculture
# 1             0.0         0.0                    AG - Crops:CH4  Agriculture
# 2             0.0         0.0                    AG - Crops:CH4  Agriculture
# 3             0.0         0.0                    AG - Crops:CH4  Agriculture
# 4             0.0         0.0                    AG - Crops:CH4  Agriculture
# ...           ...         ...                               ...          ...
# 6888          NaN         NaN  Waste - Wastewater Treatment:N2O        Waste
# 6889          NaN         NaN  Waste - Wastewater Treatment:N2O        Waste
# 6890          NaN         NaN  Waste - Wastewater Treatment:N2O        Waste
# 6891          NaN         NaN  Waste - Wastewater Treatment:N2O        Waste
# 6892          NaN         NaN  Waste - Wastewater Treatment:N2O        Waste
#
# ...

# %%
df_period_7.strategy.unique()
# Out:
# array(['Strategy TX:BASE', 'NZ', 'NDC_2', 'Historical'], dtype=object)

# %%
# Filter df_period_7 to only include rows with strategy values 'Strategy TX:BASE', 'NZ', and 'Historical'
df_period_7_filtered = df_period_7[df_period_7['strategy'].isin(['Strategy TX:BASE', 'NZ', 'Historical'])]
df_period_7_filtered
# Out:
#       strategy_id  primary_id                       Edgar_Class   CSC.Sector  \
# 0             0.0         0.0                    AG - Crops:CH4  Agriculture
# 1             0.0         0.0                    AG - Crops:CH4  Agriculture
# 2             0.0         0.0                    AG - Crops:CH4  Agriculture
# 3             0.0         0.0                    AG - Crops:CH4  Agriculture
# 4             0.0         0.0                    AG - Crops:CH4  Agriculture
# ...           ...         ...                               ...          ...
# 6888          NaN         NaN  Waste - Wastewater Treatment:N2O        Waste
# 6889          NaN         NaN  Waste - Wastewater Treatment:N2O        Waste
# 6890          NaN         NaN  Waste - Wastewater Treatment:N2O        Waste
# 6891          NaN         NaN  Waste - Wastewater Treatment:N2O        Waste
# 6892          NaN         NaN  Waste - Wastewater Treatment:N2O        Waste
#
# ...

# %%
# Filter df_period_5 to only include rows with strategy with value 'NDC_2'
df_period_5_filtered = df_period_5[df_period_5['strategy'] == 'NDC_2']
df_period_5_filtered
# Out:
#       strategy_id  primary_id                       Edgar_Class   CSC.Sector  \
# 4018       6006.0     73073.0                    AG - Crops:CH4  Agriculture
# 4019       6006.0     73073.0                    AG - Crops:CH4  Agriculture
# 4020       6006.0     73073.0                    AG - Crops:CH4  Agriculture
# 4021       6006.0     73073.0                    AG - Crops:CH4  Agriculture
# 4022       6006.0     73073.0                    AG - Crops:CH4  Agriculture
# ...           ...         ...                               ...          ...
# 6104       6006.0     73073.0  Waste - Wastewater Treatment:N2O        Waste
# 6105       6006.0     73073.0  Waste - Wastewater Treatment:N2O        Waste
# 6106       6006.0     73073.0  Waste - Wastewater Treatment:N2O        Waste
# 6107       6006.0     73073.0  Waste - Wastewater Treatment:N2O        Waste
# 6108       6006.0     73073.0  Waste - Wastewater Treatment:N2O        Waste
#
# ...

# %%
# Concat the filtered DataFrames
df_combined = pd.concat([df_period_7_filtered, df_period_5_filtered], ignore_index=True)
df_combined
# Out:
#       strategy_id  primary_id                       Edgar_Class   CSC.Sector  \
# 0             0.0         0.0                    AG - Crops:CH4  Agriculture
# 1             0.0         0.0                    AG - Crops:CH4  Agriculture
# 2             0.0         0.0                    AG - Crops:CH4  Agriculture
# 3             0.0         0.0                    AG - Crops:CH4  Agriculture
# 4             0.0         0.0                    AG - Crops:CH4  Agriculture
# ...           ...         ...                               ...          ...
# 6888       6006.0     73073.0  Waste - Wastewater Treatment:N2O        Waste
# 6889       6006.0     73073.0  Waste - Wastewater Treatment:N2O        Waste
# 6890       6006.0     73073.0  Waste - Wastewater Treatment:N2O        Waste
# 6891       6006.0     73073.0  Waste - Wastewater Treatment:N2O        Waste
# 6892       6006.0     73073.0  Waste - Wastewater Treatment:N2O        Waste
#
# ...

# %%
print(df_combined.shape)
print(df_period_5.shape)
print(df_period_7.shape)
# Out:
# (6893, 16)
# (6893, 16)
# (6893, 16)

# %%
df_combined.strategy.unique()
# Out:
# array(['Strategy TX:BASE', 'NZ', 'Historical', 'NDC_2'], dtype=object)

# %%
df_combined.to_csv(os.path.join(TABLEAU_OUTPUT_DIR, 'emissions_uganda_WIDE_INPUTS_OUTPUTS_combined_complete.csv'), index=False)

# %%
import copy
import datetime as dt
import importlib # needed so that we can reload packages
import matplotlib.pyplot as plt
import os, os.path
import numpy as np
import pandas as pd
import pathlib
import sys
import time
from typing import Union
import warnings
from datetime import datetime
warnings.filterwarnings("ignore")
import logging
from utils.logger_utils import setup_clean_logger, mute_external_loggers

# Set up a clean logger for your notebook
logger = setup_clean_logger("notebook", logging.INFO)
logger.info("Notebook started successfully.")

# Mute logs from sisepuede to avoid duplication
mute_external_loggers(["sisepuede"])


##  IMPORT SISEPUEDE EXAMPLES AND TRANSFORMERS

from sisepuede.manager.sisepuede_examples import SISEPUEDEExamples
from sisepuede.manager.sisepuede_file_structure import SISEPUEDEFileStructure
import sisepuede.core.support_classes as sc
import sisepuede.transformers as trf
import sisepuede.utilities._plotting as spu
import sisepuede.utilities._toolbox as sf
# Out:
# 2025-08-08 15:35:04,201 - INFO - Notebook started successfully.

# %%
# Save original path
original_sys_path = list(sys.path)

# Add the custom path
custom_path = os.path.abspath("../../data_processing/utils")
sys.path.append(custom_path)

# Import your module
import common_data_needs as cdn

# Revert to original sys.path
sys.path = original_sys_path
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
# Precompiling NemoMod...
# Info Given NemoMod was explicitly requested, output will be shown live
# WARNING: Method definition parse_line(String) in module ConfParser at /Users/tony/.julia/packages/ConfParser/b2fge/src/ConfParser.jl:95 overwritten in module NemoMod at /Users/tony/.julia/packages/NemoMod/p49Bn/src/other_functions.jl:35.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#    1098.7 ms  ? NemoMod
# [ Info: Precompiling NemoMod [a3c327a0-d2f0-11e8-37fd-d12fd35c3c72]
# WARNING: Method definition parse_line(String) in module ConfParser at /Users/tony/.julia/packages/ConfParser/b2fge/src/ConfParser.jl:95 overwritten in module NemoMod at /Users/tony/.julia/packages/NemoMod/p49Bn/src/other_functions.jl:35.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# ┌ Info: Skipping precompilation due to precompilable error. Importing NemoMod [a3c327a0-d2f0-11e8-37fd-d12fd35c3c72].
# └   exception = Error when precompiling module, potentially caused by a __precompile__(false) declaration in the module.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Initial Set up
#
# Make sure to edit the config yaml under ssp_modeling/config_files/config.yaml
#
# You can also create a new config yaml

# %%
# Set up dir paths

CURR_DIR_PATH = pathlib.Path(os.getcwd())
SSP_MODELING_DIR_PATH = CURR_DIR_PATH.parent
PROJECT_DIR_PATH = SSP_MODELING_DIR_PATH.parent
DATA_DIR_PATH = SSP_MODELING_DIR_PATH.joinpath("input_data")
RUN_OUTPUT_DIR_PATH = SSP_MODELING_DIR_PATH.joinpath("ssp_run_output")
SCENARIO_MAPPING_DIR_PATH = SSP_MODELING_DIR_PATH.joinpath("scenario_mapping")
CONFIG_DIR_PATH = SSP_MODELING_DIR_PATH.joinpath("config_files")
TRANSFORMATIONS_DIR_PATH = SSP_MODELING_DIR_PATH.joinpath("transformations")
MISC_DIR_PATH = SSP_MODELING_DIR_PATH.joinpath("misc")
STRATEGIES_DEFINITIONS_FILE_PATH = TRANSFORMATIONS_DIR_PATH.joinpath("strategy_definitions.csv")
STRATEGY_MAPPING_FILE_PATH = MISC_DIR_PATH.joinpath("strategy_mapping.yaml")

# %%
from ssp_transformations_handler.GeneralUtils import GeneralUtils
from ssp_transformations_handler.TransformationUtils import TransformationYamlProcessor, StrategyCSVHandler

# Initialize general utilities
g_utils = GeneralUtils()

# %%
# Load config file, double check your parameters are correct

YAML_FILE_PATH = os.path.join(CONFIG_DIR_PATH, "config_ndc_2_tunning.yaml")
config_params = g_utils.read_yaml(YAML_FILE_PATH)

country_name = config_params['country_name']
ssp_input_file_name = config_params['ssp_input_file_name']
ssp_transformation_cw = config_params['ssp_transformation_cw']
energy_model_flag = config_params['energy_model_flag']
set_lndu_reallocation_factor_to_zero_flag = config_params['set_lndu_reallocation_factor_to_zero']

# Print config parameters
logger.info(f"Country name: {country_name}")
logger.info(f"SSP input file name: {ssp_input_file_name}")
logger.info(f"SSP transformation CW: {ssp_transformation_cw}")
logger.info(f"Energy model flag: {energy_model_flag}")
logger.info(f"Set lndu reallocation factor to zero flag: {set_lndu_reallocation_factor_to_zero_flag}")
# Out:
# 2025-08-08 15:35:21,852 - INFO - Country name: uganda
# 2025-08-08 15:35:21,853 - INFO - SSP input file name: None
# 2025-08-08 15:35:21,853 - INFO - SSP transformation CW: ssp_uganda_transformation_cw_ndc_2.xlsx
# 2025-08-08 15:35:21,853 - INFO - Energy model flag: True
# 2025-08-08 15:35:21,853 - INFO - Set lndu reallocation factor to zero flag: True

# %%
# Set up SSP objects

# INPUT_FILE_PATH = DATA_DIR_PATH.joinpath(ssp_input_file_name)

# file_struct = SISEPUEDEFileStructure()

# matt = file_struct.model_attributes
# regions = sc.Regions(matt)
# time_periods = sc.TimePeriods(matt)

dict_ssp = cdn._setup_sisepuede_elements()

matt = dict_ssp.get("model_attributes", )
models = dict_ssp.get("models", )
regions = dict_ssp.get("regions", )
time_periods = dict_ssp.get("time_periods", )

# %% [markdown]
# ### Making sure our input file has the correct format and correct columns
# We use an example df with the complete fields and correct format to make sure our file is in the right shape

# %%
cdn._PATH_OUTPUTS
# Out:
# PosixPath('/Users/tony/Documents/sisepuede_modeling/ssp_uganda_data/data_processing/output_data')

# %%
df_inputs_raw = cdn._build_from_outputs(
    (
        min(time_periods.all_years),
        max(time_periods.all_years)
    ),
    fns_exclude = ["frac_lndu_initial.csv"],
    merge_type = "outer", 
    print_info = False,
    stop_on_error = True, 
)

df_inputs_raw.head()
# Out:
#    frac_agrc_nuts_cl1_temperate  yf_agrc_cereals_tonne_ha  \
# 0                      0.030468                  1.805033
# 1                      0.030468                  1.832342
# 2                      0.030468                  1.827437
# 3                      0.030468                  1.935353
# 4                      0.030468                  2.003586
#
#    frac_agrc_rice_cl2_wet  frac_agrc_cereals_cl1_tropical  \
# 0                0.988021                        0.969532
# 1                0.988021                        0.969532
# 2                0.988021                        0.969532
# 3                0.988021                        0.969532
# 4                0.988021                        0.969532
#
#    frac_agrc_tubers_cl1_tropical  frac_agrc_bevs_and_spices_cl2_wet  \
# 0                       0.969532                           0.988021
# 1                       0.969532                           0.988021
# 2                       0.969532                           0.988021
# 3                       0.969532                           0.988021
# 4                       0.969532                           0.988021
#
#    frac_agrc_tubers_cl2_wet  frac_frst_primary_cl1_temperate_nutrient_rich  \
# 0                  0.988021                                       0.015234
# 1                  0.988021                                       0.015234
# 2                  0.988021                                       0.015234
# 3                  0.988021                                       0.015234
# 4                  0.988021                                       0.015234
#
#    frac_lndu_grasslands_cl2_dry  yf_agrc_vegetables_and_vines_tonne_ha  ...  \
# 0                      0.011979                               4.002223  ...
# 1                      0.011979                               4.070985  ...
# 2                      0.011979                               4.007029  ...
# 3                      0.011979                               4.014348  ...
# 4                      0.011979                               4.035314  ...
#
#    gdp_mmm_usd  \
# 0        79.03
# 1        82.81
# 2        85.41
# 3        90.79
# 4        96.64
#
#    consumpinit_inen_energy_tj_per_mmm_gdp_other_product_manufacturing  \
# 0                                         291.931267
# 1                                         305.894321
# 2                                         315.498539
# 3                                         335.371881
# 4                                         356.981370
#
#    cost_enfu_fuel_biofuels_usd_per_m3  cost_enfu_fuel_crude_usd_per_m3  \
# 0                          521.090317                       381.062407
# 1                          521.090317                       381.062407
# 2                          521.090317                       381.062407
# 3                          521.090317                       381.062407
# 4                          521.090317                       381.062407
#
#    cost_enfu_fuel_diesel_usd_per_m3  cost_enfu_fuel_furnace_gas_usd_per_m3  \
# 0                       1573.981481                            13725.64626
# 1                       1508.786982                            13725.64626
# 2                       1416.583333                            13725.64626
# 3                       1397.178082                            13725.64626
# 4                       1380.162382                            13725.64626
#
#    cost_enfu_fuel_gasoline_usd_per_m3  cost_enfu_fuel_kerosene_usd_per_m3  \
# 0                         1610.586420                         1120.123457
# 1                         1543.875740                         1073.727811
# 2                         1449.527778                         1008.111111
# 3                         1429.671233                          994.301370
# 4                         1412.259811                          982.192152
#
#    cost_enfu_fuel_oil_usd_per_m3  time_period
# 0                     541.936245            0
# 1                     541.936245            1
# 2                     541.936245            2
# 3                     541.936245            3
# 4                     541.936245            4
#
# [5 rows x 2381 columns]

# %%
df_inputs_raw.tail()
# Out:
#     frac_agrc_nuts_cl1_temperate  yf_agrc_cereals_tonne_ha  \
# 51                      0.030468                  1.799328
# 52                      0.030468                  1.799328
# 53                      0.030468                  1.799328
# 54                      0.030468                  1.799328
# 55                      0.030468                  1.799328
#
#     frac_agrc_rice_cl2_wet  frac_agrc_cereals_cl1_tropical  \
# 51                0.988021                        0.969532
# 52                0.988021                        0.969532
# 53                0.988021                        0.969532
# 54                0.988021                        0.969532
# 55                0.988021                        0.969532
#
#     frac_agrc_tubers_cl1_tropical  frac_agrc_bevs_and_spices_cl2_wet  \
# 51                       0.969532                           0.988021
# 52                       0.969532                           0.988021
# 53                       0.969532                           0.988021
# 54                       0.969532                           0.988021
# 55                       0.969532                           0.988021
#
#     frac_agrc_tubers_cl2_wet  frac_frst_primary_cl1_temperate_nutrient_rich  \
# 51                  0.988021                                       0.015234
# 52                  0.988021                                       0.015234
# 53                  0.988021                                       0.015234
# 54                  0.988021                                       0.015234
# 55                  0.988021                                       0.015234
#
#     frac_lndu_grasslands_cl2_dry  yf_agrc_vegetables_and_vines_tonne_ha  ...  \
# 51                      0.011979                               4.030111  ...
# 52                      0.011979                               4.030111  ...
# 53                      0.011979                               4.030111  ...
# 54                      0.011979                               4.030111  ...
# 55                      0.011979                               4.030111  ...
#
#     gdp_mmm_usd  \
# 51   929.316458
# 52   947.902787
# 53   966.860843
# 54   986.198060
# 55  1005.922021
#
#     consumpinit_inen_energy_tj_per_mmm_gdp_other_product_manufacturing  \
# 51                                          421.17941
# 52                                          421.17941
# 53                                          421.17941
# 54                                          421.17941
# 55                                          421.17941
#
#     cost_enfu_fuel_biofuels_usd_per_m3  cost_enfu_fuel_crude_usd_per_m3  \
# 51                          514.896802                       376.533219
# 52                          514.763063                       376.435418
# 53                          514.629358                       376.337643
# 54                          514.495688                       376.239893
# 55                          514.362053                       376.142168
#
#     cost_enfu_fuel_diesel_usd_per_m3  cost_enfu_fuel_furnace_gas_usd_per_m3  \
# 51                       1384.476201                           13562.507565
# 52                       1384.116597                           13558.984835
# 53                       1383.757086                           13555.463021
# 54                       1383.397669                           13551.942122
# 55                       1383.038345                           13548.422137
#
#     cost_enfu_fuel_gasoline_usd_per_m3  cost_enfu_fuel_kerosene_usd_per_m3  \
# 51                         1416.673954                          985.262080
# 52                         1416.305986                          985.006168
# 53                         1415.938115                          984.750322
# 54                         1415.570338                          984.494543
# 55                         1415.202658                          984.238830
#
#     cost_enfu_fuel_oil_usd_per_m3  time_period
# 51                     535.494962           51
# 52                     535.355872           52
# 53                     535.216819           53
# 54                     535.077801           54
# 55                     534.938820           55
#
# [5 rows x 2381 columns]

# %%
##  BUILD BASE INPUTS
# df_inputs_raw = pd.read_csv(INPUT_FILE_PATH)

# pull example data to fill in gaps
examples = SISEPUEDEExamples()
df_inputs_example = examples.input_data_frame

# %%
# Double checking that our df is in the correct shape (Empty sets should be printed to make sure everything is Ok!)
g_utils.compare_dfs(df_inputs_example, df_inputs_raw)
# Out:
# Columns in df_example but not in df_input: {'region'}
# Columns in df_input but not in df_example: {'vec_ramp', 'iso_alpha_3'}

# %%
# Ensure if time_period field exist
if 'time_period' not in df_inputs_raw.columns:
    logger.info("Adding 'time_period' column to df_inputs_raw")
    df_inputs_raw = df_inputs_raw.rename(columns={'period':'time_period'})
else:
    logger.info("'time_period' column already exists in df_inputs_raw")
# Out:
# 2025-08-08 15:35:22,339 - INFO - 'time_period' column already exists in df_inputs_raw

# %%
# Fixes differences and makes sure that our df is in the correct format.
# Note: Edit this if you need more changes in your df
df_inputs_raw_complete = g_utils.add_missing_cols(df_inputs_example, df_inputs_raw.copy())
df_inputs_raw_complete = g_utils.remove_additional_cols(df_inputs_example, df_inputs_raw_complete.copy())
df_inputs_raw_complete.head()
# Out:
#    frac_agrc_nuts_cl1_temperate  yf_agrc_cereals_tonne_ha  \
# 0                      0.030468                  1.805033
# 1                      0.030468                  1.832342
# 2                      0.030468                  1.827437
# 3                      0.030468                  1.935353
# 4                      0.030468                  2.003586
#
#    frac_agrc_rice_cl2_wet  frac_agrc_cereals_cl1_tropical  \
# 0                0.988021                        0.969532
# 1                0.988021                        0.969532
# 2                0.988021                        0.969532
# 3                0.988021                        0.969532
# 4                0.988021                        0.969532
#
#    frac_agrc_tubers_cl1_tropical  frac_agrc_bevs_and_spices_cl2_wet  \
# 0                       0.969532                           0.988021
# 1                       0.969532                           0.988021
# 2                       0.969532                           0.988021
# 3                       0.969532                           0.988021
# 4                       0.969532                           0.988021
#
#    frac_agrc_tubers_cl2_wet  frac_frst_primary_cl1_temperate_nutrient_rich  \
# 0                  0.988021                                       0.015234
# 1                  0.988021                                       0.015234
# 2                  0.988021                                       0.015234
# 3                  0.988021                                       0.015234
# 4                  0.988021                                       0.015234
#
#    frac_lndu_grasslands_cl2_dry  yf_agrc_vegetables_and_vines_tonne_ha  ...  \
# 0                      0.011979                               4.002223  ...
# 1                      0.011979                               4.070985  ...
# 2                      0.011979                               4.007029  ...
# 3                      0.011979                               4.014348  ...
# 4                      0.011979                               4.035314  ...
#
#    consumpinit_inen_energy_tj_per_mmm_gdp_other_product_manufacturing  \
# 0                                         291.931267
# 1                                         305.894321
# 2                                         315.498539
# 3                                         335.371881
# 4                                         356.981370
#
#    cost_enfu_fuel_biofuels_usd_per_m3  cost_enfu_fuel_crude_usd_per_m3  \
# 0                          521.090317                       381.062407
# 1                          521.090317                       381.062407
# 2                          521.090317                       381.062407
# 3                          521.090317                       381.062407
# 4                          521.090317                       381.062407
#
#    cost_enfu_fuel_diesel_usd_per_m3  cost_enfu_fuel_furnace_gas_usd_per_m3  \
# 0                       1573.981481                            13725.64626
# 1                       1508.786982                            13725.64626
# 2                       1416.583333                            13725.64626
# 3                       1397.178082                            13725.64626
# 4                       1380.162382                            13725.64626
#
#    cost_enfu_fuel_gasoline_usd_per_m3  cost_enfu_fuel_kerosene_usd_per_m3  \
# 0                         1610.586420                         1120.123457
# 1                         1543.875740                         1073.727811
# 2                         1449.527778                         1008.111111
# 3                         1429.671233                          994.301370
# 4                         1412.259811                          982.192152
#
#    cost_enfu_fuel_oil_usd_per_m3  time_period      region
# 0                     541.936245            0  costa_rica
# 1                     541.936245            1  costa_rica
# 2                     541.936245            2  costa_rica
# 3                     541.936245            3  costa_rica
# 4                     541.936245            4  costa_rica
#
# [5 rows x 2380 columns]

# %%
# Double checking that our df is in the correct shape (Empty sets should be printed to make sure everything is Ok!)
g_utils.compare_dfs(df_inputs_example, df_inputs_raw_complete)
# Out:
# Columns in df_example but not in df_input: set()
# Columns in df_input but not in df_example: set()

# %%
# Check region values
df_inputs_raw_complete['region'].unique()
# Out:
# array(['costa_rica', nan], dtype=object)

# %%
# Set region to country name
df_inputs_raw_complete['region'] = country_name
df_inputs_raw_complete['region'].unique()
# Out:
# array(['uganda'], dtype=object)

# %% [markdown]
# ## Let's Modify the  LNDU Reallocation factor

# %%
if set_lndu_reallocation_factor_to_zero_flag:
    df_inputs_raw_complete['lndu_reallocation_factor'] = 0

df_inputs_raw_complete['lndu_reallocation_factor'].mean()
# Out:
# np.float64(0.0)

# %%
# Get fields with nulls
fields_with_nulls = df_inputs_raw_complete.columns[df_inputs_raw_complete.isnull().any()].tolist()
fields_with_nulls
# Out:
# []

# %%
df_inputs_raw_complete
# Out:
#     frac_agrc_nuts_cl1_temperate  yf_agrc_cereals_tonne_ha  \
# 0                       0.030468                  1.805033
# 1                       0.030468                  1.832342
# 2                       0.030468                  1.827437
# 3                       0.030468                  1.935353
# 4                       0.030468                  2.003586
# 5                       0.030468                  2.076421
# 6                       0.030468                  2.758779
# 7                       0.030468                  1.799328
# 8                       0.030468                  1.799328
# 9                       0.030468                  1.799328
# 10                      0.030468                  1.799328
# 11                      0.030468                  1.799328
# 12                      0.030468                  1.799328
# 13                      0.030468                  1.799328
# 14                      0.030468                  1.799328
# 15                      0.030468                  1.799328
# 16                      0.030468                  1.799328
# 17                      0.030468                  1.799328
# 18                      0.030468                  1.799328
# 19                      0.030468                  1.799328
# 20                      0.030468                  1.799328
# 21                      0.030468                  1.799328
# 22                      0.030468                  1.799328
# 23                      0.030468                  1.799328
# 24                      0.030468                  1.799328
# 25                      0.030468                  1.799328
# 26                      0.030468                  1.799328
# 27                      0.030468                  1.799328
# 28                      0.030468                  1.799328
# 29                      0.030468                  1.799328
# 30                      0.030468                  1.799328
# 31                      0.030468                  1.799328
# 32                      0.030468                  1.799328
# 33                      0.030468                  1.799328
# 34                      0.030468                  1.799328
# 35                      0.030468                  1.799328
# 36                      0.030468                  1.799328
# 37                      0.030468                  1.799328
# 38                      0.030468                  1.799328
# 39                      0.030468                  1.799328
# 40                      0.030468                  1.799328
# 41                      0.030468                  1.799328
# 42                      0.030468                  1.799328
# 43                      0.030468                  1.799328
# 44                      0.030468                  1.799328
# 45                      0.030468                  1.799328
# 46                      0.030468                  1.799328
# 47                      0.030468                  1.799328
# 48                      0.030468                  1.799328
# 49                      0.030468                  1.799328
# 50                      0.030468                  1.799328
# 51                      0.030468                  1.799328
# 52                      0.030468                  1.799328
# 53                      0.030468                  1.799328
# 54                      0.030468                  1.799328
# 55                      0.030468                  1.799328
#
#     frac_agrc_rice_cl2_wet  frac_agrc_cereals_cl1_tropical  \
# 0                 0.988021                        0.969532
# 1                 0.988021                        0.969532
# 2                 0.988021                        0.969532
# 3                 0.988021                        0.969532
# 4                 0.988021                        0.969532
# 5                 0.988021                        0.969532
# 6                 0.988021                        0.969532
# 7                 0.988021                        0.969532
# 8                 0.988021                        0.969532
# 9                 0.988021                        0.969532
# 10                0.988021                        0.969532
# 11                0.988021                        0.969532
# 12                0.988021                        0.969532
# 13                0.988021                        0.969532
# 14                0.988021                        0.969532
# 15                0.988021                        0.969532
# 16                0.988021                        0.969532
# 17                0.988021                        0.969532
# 18                0.988021                        0.969532
# 19                0.988021                        0.969532
# 20                0.988021                        0.969532
# 21                0.988021                        0.969532
# 22                0.988021                        0.969532
# 23                0.988021                        0.969532
# 24                0.988021                        0.969532
# 25                0.988021                        0.969532
# 26                0.988021                        0.969532
# 27                0.988021                        0.969532
# 28                0.988021                        0.969532
# 29                0.988021                        0.969532
# 30                0.988021                        0.969532
# 31                0.988021                        0.969532
# 32                0.988021                        0.969532
# 33                0.988021                        0.969532
# 34                0.988021                        0.969532
# 35                0.988021                        0.969532
# 36                0.988021                        0.969532
# 37                0.988021                        0.969532
# 38                0.988021                        0.969532
# 39                0.988021                        0.969532
# 40                0.988021                        0.969532
# 41                0.988021                        0.969532
# 42                0.988021                        0.969532
# 43                0.988021                        0.969532
# 44                0.988021                        0.969532
# 45                0.988021                        0.969532
# 46                0.988021                        0.969532
# 47                0.988021                        0.969532
# 48                0.988021                        0.969532
# 49                0.988021                        0.969532
# 50                0.988021                        0.969532
# 51                0.988021                        0.969532
# 52                0.988021                        0.969532
# 53                0.988021                        0.969532
# 54                0.988021                        0.969532
# 55                0.988021                        0.969532
#
#     frac_agrc_tubers_cl1_tropical  frac_agrc_bevs_and_spices_cl2_wet  \
# 0                        0.969532                           0.988021
# 1                        0.969532                           0.988021
# 2                        0.969532                           0.988021
# 3                        0.969532                           0.988021
# 4                        0.969532                           0.988021
# 5                        0.969532                           0.988021
# 6                        0.969532                           0.988021
# 7                        0.969532                           0.988021
# 8                        0.969532                           0.988021
# 9                        0.969532                           0.988021
# 10                       0.969532                           0.988021
# 11                       0.969532                           0.988021
# 12                       0.969532                           0.988021
# 13                       0.969532                           0.988021
# 14                       0.969532                           0.988021
# 15                       0.969532                           0.988021
# 16                       0.969532                           0.988021
# 17                       0.969532                           0.988021
# 18                       0.969532                           0.988021
# 19                       0.969532                           0.988021
# 20                       0.969532                           0.988021
# 21                       0.969532                           0.988021
# 22                       0.969532                           0.988021
# 23                       0.969532                           0.988021
# 24                       0.969532                           0.988021
# 25                       0.969532                           0.988021
# 26                       0.969532                           0.988021
# 27                       0.969532                           0.988021
# 28                       0.969532                           0.988021
# 29                       0.969532                           0.988021
# 30                       0.969532                           0.988021
# 31                       0.969532                           0.988021
# 32                       0.969532                           0.988021
# 33                       0.969532                           0.988021
# 34                       0.969532                           0.988021
# 35                       0.969532                           0.988021
# 36                       0.969532                           0.988021
# 37                       0.969532                           0.988021
# 38                       0.969532                           0.988021
# 39                       0.969532                           0.988021
# 40                       0.969532                           0.988021
# 41                       0.969532                           0.988021
# 42                       0.969532                           0.988021
# 43                       0.969532                           0.988021
# 44                       0.969532                           0.988021
# 45                       0.969532                           0.988021
# 46                       0.969532                           0.988021
# 47                       0.969532                           0.988021
# 48                       0.969532                           0.988021
# 49                       0.969532                           0.988021
# 50                       0.969532                           0.988021
# 51                       0.969532                           0.988021
# 52                       0.969532                           0.988021
# 53                       0.969532                           0.988021
# 54                       0.969532                           0.988021
# 55                       0.969532                           0.988021
#
#     frac_agrc_tubers_cl2_wet  frac_frst_primary_cl1_temperate_nutrient_rich  \
# 0                   0.988021                                       0.015234
# 1                   0.988021                                       0.015234
# 2                   0.988021                                       0.015234
# 3                   0.988021                                       0.015234
# 4                   0.988021                                       0.015234
# 5                   0.988021                                       0.015234
# 6                   0.988021                                       0.015234
# 7                   0.988021                                       0.015234
# 8                   0.988021                                       0.015234
# 9                   0.988021                                       0.015234
# 10                  0.988021                                       0.015234
# 11                  0.988021                                       0.015234
# 12                  0.988021                                       0.015234
# 13                  0.988021                                       0.015234
# 14                  0.988021                                       0.015234
# 15                  0.988021                                       0.015234
# 16                  0.988021                                       0.015234
# 17                  0.988021                                       0.015234
# 18                  0.988021                                       0.015234
# 19                  0.988021                                       0.015234
# 20                  0.988021                                       0.015234
# 21                  0.988021                                       0.015234
# 22                  0.988021                                       0.015234
# 23                  0.988021                                       0.015234
# 24                  0.988021                                       0.015234
# 25                  0.988021                                       0.015234
# 26                  0.988021                                       0.015234
# 27                  0.988021                                       0.015234
# 28                  0.988021                                       0.015234
# 29                  0.988021                                       0.015234
# 30                  0.988021                                       0.015234
# 31                  0.988021                                       0.015234
# 32                  0.988021                                       0.015234
# 33                  0.988021                                       0.015234
# 34                  0.988021                                       0.015234
# 35                  0.988021                                       0.015234
# 36                  0.988021                                       0.015234
# 37                  0.988021                                       0.015234
# 38                  0.988021                                       0.015234
# 39                  0.988021                                       0.015234
# 40                  0.988021                                       0.015234
# 41                  0.988021                                       0.015234
# 42                  0.988021                                       0.015234
# 43                  0.988021                                       0.015234
# 44                  0.988021                                       0.015234
# 45                  0.988021                                       0.015234
# 46                  0.988021                                       0.015234
# 47                  0.988021                                       0.015234
# 48                  0.988021                                       0.015234
# 49                  0.988021                                       0.015234
# 50                  0.988021                                       0.015234
# 51                  0.988021                                       0.015234
# 52                  0.988021                                       0.015234
# 53                  0.988021                                       0.015234
# 54                  0.988021                                       0.015234
# 55                  0.988021                                       0.015234
#
#     frac_lndu_grasslands_cl2_dry  yf_agrc_vegetables_and_vines_tonne_ha  ...  \
# 0                       0.011979                               4.002223  ...
# 1                       0.011979                               4.070985  ...
# 2                       0.011979                               4.007029  ...
# 3                       0.011979                               4.014348  ...
# 4                       0.011979                               4.035314  ...
# 5                       0.011979                               4.013004  ...
# 6                       0.011979                               4.023409  ...
# 7                       0.011979                               4.030111  ...
# 8                       0.011979                               4.030111  ...
# 9                       0.011979                               4.030111  ...
# 10                      0.011979                               4.030111  ...
# 11                      0.011979                               4.030111  ...
# 12                      0.011979                               4.030111  ...
# 13                      0.011979                               4.030111  ...
# 14                      0.011979                               4.030111  ...
# 15                      0.011979                               4.030111  ...
# 16                      0.011979                               4.030111  ...
# 17                      0.011979                               4.030111  ...
# 18                      0.011979                               4.030111  ...
# 19                      0.011979                               4.030111  ...
# 20                      0.011979                               4.030111  ...
# 21                      0.011979                               4.030111  ...
# 22                      0.011979                               4.030111  ...
# 23                      0.011979                               4.030111  ...
# 24                      0.011979                               4.030111  ...
# 25                      0.011979                               4.030111  ...
# 26                      0.011979                               4.030111  ...
# 27                      0.011979                               4.030111  ...
# 28                      0.011979                               4.030111  ...
# 29                      0.011979                               4.030111  ...
# 30                      0.011979                               4.030111  ...
# 31                      0.011979                               4.030111  ...
# 32                      0.011979                               4.030111  ...
# 33                      0.011979                               4.030111  ...
# 34                      0.011979                               4.030111  ...
# 35                      0.011979                               4.030111  ...
# 36                      0.011979                               4.030111  ...
# 37                      0.011979                               4.030111  ...
# 38                      0.011979                               4.030111  ...
# 39                      0.011979                               4.030111  ...
# 40                      0.011979                               4.030111  ...
# 41                      0.011979                               4.030111  ...
# 42                      0.011979                               4.030111  ...
# 43                      0.011979                               4.030111  ...
# 44                      0.011979                               4.030111  ...
# 45                      0.011979                               4.030111  ...
# 46                      0.011979                               4.030111  ...
# 47                      0.011979                               4.030111  ...
# 48                      0.011979                               4.030111  ...
# 49                      0.011979                               4.030111  ...
# 50                      0.011979                               4.030111  ...
# 51                      0.011979                               4.030111  ...
# 52                      0.011979                               4.030111  ...
# 53                      0.011979                               4.030111  ...
# 54                      0.011979                               4.030111  ...
# 55                      0.011979                               4.030111  ...
#
#     consumpinit_inen_energy_tj_per_mmm_gdp_other_product_manufacturing  \
# 0                                          291.931267
# 1                                          305.894321
# 2                                          315.498539
# 3                                          335.371881
# 4                                          356.981370
# 5                                          367.509069
# 6                                          380.511702
# 7                                          397.947050
# 8                                          421.179410
# 9                                          421.179410
# 10                                         421.179410
# 11                                         421.179410
# 12                                         421.179410
# 13                                         421.179410
# 14                                         421.179410
# 15                                         421.179410
# 16                                         421.179410
# 17                                         421.179410
# 18                                         421.179410
# 19                                         421.179410
# 20                                         421.179410
# 21                                         421.179410
# 22                                         421.179410
# 23                                         421.179410
# 24                                         421.179410
# 25                                         421.179410
# 26                                         421.179410
# 27                                         421.179410
# 28                                         421.179410
# 29                                         421.179410
# 30                                         421.179410
# 31                                         421.179410
# 32                                         421.179410
# 33                                         421.179410
# 34                                         421.179410
# 35                                         421.179410
# 36                                         421.179410
# 37                                         421.179410
# 38                                         421.179410
# 39                                         421.179410
# 40                                         421.179410
# 41                                         421.179410
# 42                                         421.179410
# 43                                         421.179410
# 44                                         421.179410
# 45                                         421.179410
# 46                                         421.179410
# 47                                         421.179410
# 48                                         421.179410
# 49                                         421.179410
# 50                                         421.179410
# 51                                         421.179410
# 52                                         421.179410
# 53                                         421.179410
# 54                                         421.179410
# 55                                         421.179410
#
#     cost_enfu_fuel_biofuels_usd_per_m3  cost_enfu_fuel_crude_usd_per_m3  \
# 0                           521.090317                       381.062407
# 1                           521.090317                       381.062407
# 2                           521.090317                       381.062407
# 3                           521.090317                       381.062407
# 4                           521.090317                       381.062407
# 5                           521.090317                       381.062407
# 6                           521.063082                       381.042490
# 7                           521.008616                       381.002660
# 8                           520.926925                       380.942921
# 9                           520.818020                       380.863281
# 10                          520.681918                       380.763753
# 11                          520.518638                       380.644349
# 12                          520.328204                       380.505089
# 13                          520.144355                       380.370644
# 14                          519.967084                       380.241010
# 15                          519.796383                       380.116180
# 16                          519.632248                       379.996151
# 17                          519.474670                       379.880918
# 18                          519.323644                       379.770476
# 19                          519.179165                       379.664821
# 20                          519.041227                       379.563950
# 21                          518.909824                       379.467858
# 22                          518.778113                       379.371540
# 23                          518.646094                       379.274998
# 24                          518.513768                       379.178231
# 25                          518.381135                       379.081239
# 26                          518.248195                       378.984023
# 27                          518.114948                       378.886582
# 28                          517.981395                       378.788917
# 29                          517.847536                       378.691029
# 30                          517.713370                       378.592916
# 31                          517.578899                       378.494581
# 32                          517.444463                       378.396270
# 33                          517.310062                       378.297986
# 34                          517.175696                       378.199726
# 35                          517.041365                       378.101493
# 36                          516.907068                       378.003285
# 37                          516.772807                       377.905102
# 38                          516.638580                       377.806945
# 39                          516.504388                       377.708813
# 40                          516.370231                       377.610707
# 41                          516.236109                       377.512626
# 42                          516.102022                       377.414571
# 43                          515.967969                       377.316541
# 44                          515.833952                       377.218537
# 45                          515.699969                       377.120558
# 46                          515.566021                       377.022605
# 47                          515.432107                       376.924677
# 48                          515.298229                       376.826774
# 49                          515.164385                       376.728897
# 50                          515.030576                       376.631045
# 51                          514.896802                       376.533219
# 52                          514.763063                       376.435418
# 53                          514.629358                       376.337643
# 54                          514.495688                       376.239893
# 55                          514.362053                       376.142168
#
#     cost_enfu_fuel_diesel_usd_per_m3  cost_enfu_fuel_furnace_gas_usd_per_m3  \
# 0                        1573.981481                           13725.646260
# 1                        1508.786982                           13725.646260
# 2                        1416.583333                           13725.646260
# 3                        1397.178082                           13725.646260
# 4                        1380.162382                           13725.646260
# 5                        1381.658087                           13725.646260
# 6                        1439.779785                           13724.928892
# 7                        1350.913907                           13723.494230
# 8                        1390.321701                           13721.342463
# 9                        1386.164719                           13718.473889
# 10                       1395.266758                           13714.888922
# 11                       1399.592429                           13710.588086
# 12                       1399.080383                           13705.572017
# 13                       1398.586043                           13700.729391
# 14                       1398.109388                           13696.060023
# 15                       1397.650402                           13691.563735
# 16                       1397.209066                           13687.240355
# 17                       1396.785365                           13683.089719
# 18                       1396.379281                           13679.111667
# 19                       1395.990799                           13675.306048
# 20                       1395.619904                           13671.672717
# 21                       1395.266583                           13668.211534
# 22                       1394.912433                           13664.742239
# 23                       1394.557456                           13661.264840
# 24                       1394.201653                           13657.779342
# 25                       1393.845023                           13654.285753
# 26                       1393.487568                           13650.784078
# 27                       1393.129289                           13647.274325
# 28                       1392.770185                           13643.756501
# 29                       1392.410258                           13640.230612
# 30                       1392.049509                           13636.696664
# 31                       1391.687938                           13633.154665
# 32                       1391.326460                           13629.613586
# 33                       1390.965077                           13626.073426
# 34                       1390.603787                           13622.534186
# 35                       1390.242591                           13618.995866
# 36                       1389.881489                           13615.458464
# 37                       1389.520481                           13611.921982
# 38                       1389.159567                           13608.386417
# 39                       1388.798746                           13604.851772
# 40                       1388.438019                           13601.318044
# 41                       1388.077386                           13597.785234
# 42                       1387.716846                           13594.253342
# 43                       1387.356400                           13590.722367
# 44                       1386.996048                           13587.192309
# 45                       1386.635789                           13583.663168
# 46                       1386.275624                           13580.134944
# 47                       1385.915553                           13576.607636
# 48                       1385.555575                           13573.081245
# 49                       1385.195690                           13569.555769
# 50                       1384.835899                           13566.031209
# 51                       1384.476201                           13562.507565
# 52                       1384.116597                           13558.984835
# 53                       1383.757086                           13555.463021
# 54                       1383.397669                           13551.942122
# 55                       1383.038345                           13548.422137
#
#     cost_enfu_fuel_gasoline_usd_per_m3  cost_enfu_fuel_kerosene_usd_per_m3  \
# 0                          1610.586420                         1120.123457
# 1                          1543.875740                         1073.727811
# 2                          1449.527778                         1008.111111
# 3                          1429.671233                          994.301370
# 4                          1412.259811                          982.192152
# 5                          1413.790301                          983.256570
# 6                          1473.263693                         1024.618859
# 7                          1382.331126                          961.377483
# 8                          1422.655398                          989.422028
# 9                          1418.401740                          986.463713
# 10                         1427.715458                          992.941176
# 11                         1432.141729                          996.019539
# 12                         1431.617774                          995.655142
# 13                         1431.111937                          995.303344
# 14                         1430.624198                          994.964133
# 15                         1430.154537                          994.637496
# 16                         1429.702938                          994.323420
# 17                         1429.269382                          994.021893
# 18                         1428.853854                          993.732903
# 19                         1428.456338                          993.456440
# 20                         1428.076817                          993.192493
# 21                         1427.715279                          992.941052
# 22                         1427.352893                          992.689021
# 23                         1426.989661                          992.436402
# 24                         1426.625583                          992.183195
# 25                         1426.260659                          991.929399
# 26                         1425.894891                          991.675017
# 27                         1425.528279                          991.420047
# 28                         1425.160825                          991.164491
# 29                         1424.792527                          990.908349
# 30                         1424.423388                          990.651622
# 31                         1424.053408                          990.394310
# 32                         1423.683524                          990.137065
# 33                         1423.313736                          989.879886
# 34                         1422.944044                          989.622775
# 35                         1422.574448                          989.365730
# 36                         1422.204948                          989.108752
# 37                         1421.835545                          988.851840
# 38                         1421.466237                          988.594996
# 39                         1421.097025                          988.338218
# 40                         1420.727909                          988.081507
# 41                         1420.358888                          987.824862
# 42                         1419.989964                          987.568284
# 43                         1419.621135                          987.311773
# 44                         1419.252403                          987.055328
# 45                         1418.883766                          986.798950
# 46                         1418.515224                          986.542639
# 47                         1418.146779                          986.286394
# 48                         1417.778429                          986.030216
# 49                         1417.410175                          985.774104
# 50                         1417.042016                          985.518059
# 51                         1416.673954                          985.262080
# 52                         1416.305986                          985.006168
# 53                         1415.938115                          984.750322
# 54                         1415.570338                          984.494543
# 55                         1415.202658                          984.238830
#
#     cost_enfu_fuel_oil_usd_per_m3  time_period  region
# 0                      541.936245            0  uganda
# 1                      541.936245            1  uganda
# 2                      541.936245            2  uganda
# 3                      541.936245            3  uganda
# 4                      541.936245            4  uganda
# 5                      541.936245            5  uganda
# 6                      541.907921            6  uganda
# 7                      541.851275            7  uganda
# 8                      541.766316            8  uganda
# 9                      541.653055            9  uganda
# 10                     541.511508           10  uganda
# 11                     541.341696           11  uganda
# 12                     541.143644           12  uganda
# 13                     540.952440           13  uganda
# 14                     540.768077           14  uganda
# 15                     540.590548           15  uganda
# 16                     540.419846           16  uganda
# 17                     540.255965           17  uganda
# 18                     540.098897           18  uganda
# 19                     539.948638           19  uganda
# 20                     539.805182           20  uganda
# 21                     539.668522           21  uganda
# 22                     539.531542           22  uganda
# 23                     539.394243           23  uganda
# 24                     539.256623           24  uganda
# 25                     539.118684           25  uganda
# 26                     538.980426           26  uganda
# 27                     538.841848           27  uganda
# 28                     538.702952           28  uganda
# 29                     538.563738           29  uganda
# 30                     538.424205           30  uganda
# 31                     538.284355           31  uganda
# 32                     538.144541           32  uganda
# 33                     538.004763           33  uganda
# 34                     537.865022           34  uganda
# 35                     537.725316           35  uganda
# 36                     537.585648           36  uganda
# 37                     537.446015           37  uganda
# 38                     537.306419           38  uganda
# 39                     537.166858           39  uganda
# 40                     537.027335           40  uganda
# 41                     536.887847           41  uganda
# 42                     536.748396           42  uganda
# 43                     536.608980           43  uganda
# 44                     536.469601           44  uganda
# 45                     536.330259           45  uganda
# 46                     536.190952           46  uganda
# 47                     536.051682           47  uganda
# 48                     535.912448           48  uganda
# 49                     535.773249           49  uganda
# 50                     535.634088           50  uganda
# 51                     535.494962           51  uganda
# 52                     535.355872           52  uganda
# 53                     535.216819           53  uganda
# 54                     535.077801           54  uganda
# 55                     534.938820           55  uganda
#
# [56 rows x 2380 columns]

# %%
df_inputs_raw_complete.shape
# Out:
# (56, 2380)

# %% [markdown]
# #  Let's try building transformations using this

# %%
transformers = trf.transformers.Transformers(
    {},
    attr_time_period = cdn._ATTRIBUTE_TABLE_TIME_PERIOD,
    df_input = df_inputs_raw_complete,
)

# %% [markdown]
# ##  Instantiate some transformations. Make sure to run this cell to create the transformations folder for the first time or if you wish to overwrite

# %%
# set an ouput path and instantiate
if not TRANSFORMATIONS_DIR_PATH.exists():
    trf.instantiate_default_strategy_directory(
        transformers,
        TRANSFORMATIONS_DIR_PATH,
    )
else:
    logger.info(f"Directory {TRANSFORMATIONS_DIR_PATH} already exists. Skipping instantiation.")
# Out:
# 2025-08-08 15:35:22,865 - INFO - Directory /Users/tony/Documents/sisepuede_modeling/ssp_uganda_data/ssp_modeling/transformations already exists. Skipping instantiation.

# %% [markdown]
# ##  --HERE, CUSTOMIZE YOUR TRANSFORMATIONS AND STRATEGIES--

# %% [markdown]
# ### Customizing transformations and strategies files using TransformationUtils.py classes

# %%
# Generate new transformation files based on the excel mapping file. 
# Make sure to have the most updated format for the excel file, check the one used in this notebook for reference.

if ssp_transformation_cw is None:
    logger.warning("ssp_transformation_cw is not defined. Please check your config file.")
else:
    logger.info(f"Using transformation file: {ssp_transformation_cw}")
    cw_file_path = os.path.join(SCENARIO_MAPPING_DIR_PATH, ssp_transformation_cw)
    logger.info(f"Transformation file path: {cw_file_path}")
    excel_yaml_handler = TransformationYamlProcessor(scenario_mapping_excel_path=cw_file_path, yaml_dir_path=TRANSFORMATIONS_DIR_PATH)
# Out:
# 2025-08-08 15:35:22,877 - INFO - Using transformation file: ssp_uganda_transformation_cw_ndc_2.xlsx
# 2025-08-08 15:35:22,877 - INFO - Transformation file path: /Users/tony/Documents/sisepuede_modeling/ssp_uganda_data/ssp_modeling/scenario_mapping/ssp_uganda_transformation_cw_ndc_2.xlsx

# %%
# This creates transformation yaml files for each strategy in the excel file
if ssp_transformation_cw is not None:
    logger.info("Processing YAML files...")
    excel_yaml_handler.process_yaml_files()
else:
    logger.warning("ssp_transformation_cw is not defined. Please check your config file.")
# Out:
# 2025-08-08 15:35:22,963 - INFO - Processing YAML files...
# ==================================================
# [transformation_agrc_inc_conservation_agriculture.yaml | TX:AGRC:INC_CONSERVATION_AGRICULTURE] Expand conservation agriculture (AGRC) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# YAML file transformation_agrc_inc_conservation_agriculture.yaml already exists for strategy strategy_NDC_2. Please check manually.
# ==================================================
# [transformation_agrc_inc_productivity.yaml | TX:AGRC:INC_PRODUCTIVITY] Improve crop productivity (AGRC) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_entc_dec_losses.yaml | TX:ENTC:DEC_LOSSES] Reduce transmission losses (ENTC) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_entc_target_renewable_elec.yaml | TX:ENTC:TARGET_RENEWABLE_ELEC] 95% of electricity is generated by renewables in 2050 (ENTC) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_inen_inc_efficiency_energy.yaml | TX:INEN:INC_EFFICIENCY_ENERGY] Maximize industrial energy efficiency (INEN) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_inen_inc_efficiency_production.yaml | TX:INEN:INC_EFFICIENCY_PRODUCTION] Maximize industrial production efficiency (INEN) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_inen_shift_fuel_heat.yaml | TX:INEN:SHIFT_FUEL_HEAT] Fuel switch high- and low-temp thermal processes.  (INEN) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# YAML file transformation_inen_shift_fuel_heat.yaml already exists for strategy strategy_NDC_2. Please check manually.
# ==================================================
# [transformation_ippu_dec_clinker.yaml | TX:IPPU:DEC_CLINKER] Reduce cement clinker (IPPU) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_ippu_dec_hfcs.yaml | TX:IPPU:DEC_HFCS] Reduce use of HFCs (IPPU) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_lndu_dec_deforestation.yaml | TX:LNDU:DEC_DEFORESTATION] Stop deforestation (LNDU) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_lndu_inc_reforestation.yaml | TX:LNDU:INC_REFORESTATION] Increase Reforestation (LNDU) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_lvst_dec_enteric_fermentation.yaml | TX:LVST:DEC_ENTERIC_FERMENTATION] Reduce enteric fermentation (LVST) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# YAML file transformation_lvst_dec_enteric_fermentation.yaml already exists for strategy strategy_NDC_2. Please check manually.
# ==================================================
# [transformation_lvst_inc_productivity.yaml | TX:LVST:INC_PRODUCTIVITY] Increase livestock productivity (LVST) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_scoe_dec_demand_heat.yaml | TX:SCOE:DEC_DEMAND_HEAT] Reduce end-use demand for heat energy by improving building shell (SCOE) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_scoe_shift_fuel_heat.yaml | TX:SCOE:SHIFT_FUEL_HEAT] Switch to electricity for heat using heat pumps, electric stoves, etc. (SCOE) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_trns_inc_efficiency_non_electric.yaml | TX:TRNS:INC_EFFICIENCY_NON_ELECTRIC] Increase non-electric transportation energy efficiency (TRNS) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_trns_shift_fuel_light_duty.yaml | TX:TRNS:SHIFT_FUEL_LIGHT_DUTY] Electrify light duty road transport (TRNS) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_trns_shift_fuel_medium_duty.yaml | TX:TRNS:SHIFT_FUEL_MEDIUM_DUTY] Fuel switch medium duty road transport (TRNS) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_trns_shift_mode_freight.yaml | TX:TRNS:SHIFT_MODE_FREIGHT] Mode shift freight (TRNS) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_trns_shift_mode_passenger.yaml | TX:TRNS:SHIFT_MODE_PASSENGER] Mode shift passenger vehicles to others (TRNS) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_trww_inc_compliance_septic.yaml | TX:TRWW:INC_COMPLIANCE_SEPTIC] Increase septic compliance (TRWW) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_wali_inc_treatment_industrial.yaml | TX:WALI:INC_TREATMENT_INDUSTRIAL] Improved industrial wastewater treatment (WALI) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# YAML file transformation_wali_inc_treatment_industrial.yaml already exists for strategy strategy_NDC_2. Please check manually.
# ==================================================
# [transformation_wali_inc_treatment_rural.yaml | TX:WALI:INC_TREATMENT_RURAL] Improved rural wastewater treatment (WALI) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# YAML file transformation_wali_inc_treatment_rural.yaml already exists for strategy strategy_NDC_2. Please check manually.
# ==================================================
# [transformation_wali_inc_treatment_urban.yaml | TX:WALI:INC_TREATMENT_URBAN] Improved urban wastewater treatment (WALI) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# YAML file transformation_wali_inc_treatment_urban.yaml already exists for strategy strategy_NDC_2. Please check manually.
# ==================================================
# [transformation_waso_dec_consumer_food_waste.yaml | TX:WASO:DEC_CONSUMER_FOOD_WASTE] Consumer food waste reduction (WASO) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_waso_inc_anaerobic_and_compost.yaml | TX:WASO:INC_ANAEROBIC_AND_COMPOST] Increase composting and biogas (WASO) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# YAML file transformation_waso_inc_anaerobic_and_compost.yaml already exists for strategy strategy_NDC_2. Please check manually.
# ==================================================
# [transformation_waso_inc_capture_biogas.yaml | TX:WASO:INC_CAPTURE_BIOGAS] Increase biogas capture (WASO) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_waso_inc_landfilling.yaml | TX:WASO:INC_LANDFILLING] Increase landfilling (WASO) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================
# ==================================================
# [transformation_waso_inc_recycling.yaml | TX:WASO:INC_RECYCLING] Increase recycling (WASO) | Start: 5
# Strategy: strategy_NDC_2, Scalar value: 1.0
# ==================================================

# %%
# Load the transformations per strategy dictionary so we can pass it to the strategy handler
# You can also check here if the transformations in each strategy are correct

if ssp_transformation_cw is not None:
    logger.info("Loading transformations per strategy dictionary...")
    transformation_per_strategy_dict = excel_yaml_handler.get_transformations_per_strategy_dict()
    transformation_per_strategy_dict
    logger.info(f"Loaded transformations for strategies: {transformation_per_strategy_dict.keys()}")
else:
    logger.warning("No transformation handler available. Please check your config file.")
# Out:
# 2025-08-08 15:35:22,994 - INFO - Loading transformations per strategy dictionary...
# 2025-08-08 15:35:22,995 - INFO - Loaded transformations for strategies: dict_keys(['strategy_NDC_2'])

# %% [markdown]
# ### Creating new strategies
# - You can create new strategies from scratch.
# - You can also update existing ones.

# %%
# Creating new strategies by updating the strategy_definitions file.

if ssp_transformation_cw is not None:
    # You can edit this to add yours, as many as you want.
    csv_handler = StrategyCSVHandler(csv_file_path=STRATEGIES_DEFINITIONS_FILE_PATH, 
                                     yaml_dir_path=TRANSFORMATIONS_DIR_PATH, 
                                     yaml_mapping_file=STRATEGY_MAPPING_FILE_PATH, 
                                     transformation_per_strategy_dict=transformation_per_strategy_dict)
    
    for strategy_name in transformation_per_strategy_dict.keys():
        yaml_file_suffix = strategy_name.split('strategy_')[-1]
        csv_handler.add_strategy(strategy_group='PFLO', description='Custom Strategy', yaml_file_suffix=yaml_file_suffix)

else:
    logger.warning("No transformation handler available. Please check your config file.")
# Out:
# INFO: Strategy code PFLO:NDC_2 already exists in the strategy definitions. Strategy will be updated...
# Updated row with strategy_code PFLO:NDC_2

# %%
# Set up the strategy codes you wish to run in ssp
strategies_to_run = [0, 6006]
logger.info(f"Strategies to run: {strategies_to_run}")
# Out:
# 2025-08-08 15:35:23,032 - INFO - Strategies to run: [0, 6006]

# %% [markdown]
# ### We finished adding new transformation files and strategies so lets load them back

# %%
# then, you can load this back in after modifying (play around with it)
transformations = trf.Transformations(
    TRANSFORMATIONS_DIR_PATH,
    transformers = transformers,
)
tab = transformations.attribute_transformation.table

# %%
#  build the strategies -- will export to path
t0 = time.time()
strategies = trf.Strategies(
    transformations,
    export_path = "transformations",
    prebuild = True,
)

t_elapse = sf.get_time_elapsed(t0)
logger.info(f"Strategies defined at {strategies.transformations.dir_init} initialized in {t_elapse} seconds")
# Out:
# 2025-08-08 15:35:25,575 - INFO - Strategies defined at /Users/tony/Documents/sisepuede_modeling/ssp_uganda_data/ssp_modeling/transformations initialized in 2.43 seconds

# %%
strategies.attribute_table
# Out:
#     strategy_id                      strategy_code  \
# 0             0                               BASE
# 1          1000                  AGRC:DEC_CH4_RICE
# 2          1001                   AGRC:DEC_EXPORTS
# 3          1002       AGRC:DEC_LOSSES_SUPPLY_CHAIN
# 4          1003  AGRC:INC_CONSERVATION_AGRICULTURE
# ..          ...                                ...
# 69         6002                           PFLO:ALL
# 70         6003                           PFLO:NDC
# 71         6004                            PFLO:NZ
# 72         6005                           PFLO:BAU
# 73         6006                         PFLO:NDC_2
#
#                                              strategy  \
# 0                                    Strategy TX:BASE
# 1   Singleton - Default Value - AGRC: Improve rice...
# 2   Singleton - Default Value - AGRC: Decrease Exp...
# 3   Singleton - Default Value - AGRC: Reduce suppl...
# 4   Singleton - Default Value - AGRC: Expand conse...
# ..                                                ...
# 69                                        All Actions
# 70                                                NDC
# 71                                                 NZ
# 72                                                BAU
# 73                                              NDC_2
#
#                             description  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 69  All actions (unique by transformer)
# 70                          NDC Pathway
# 71                      Custom Strategy
# 72                      Custom Strategy
# 73                      Custom Strategy
#
#                          transformation_specification  baseline_strategy_id
# 0                                             TX:BASE                     1
# 1                                TX:AGRC:DEC_CH4_RICE                     0
# 2                                 TX:AGRC:DEC_EXPORTS                     0
# 3                     TX:AGRC:DEC_LOSSES_SUPPLY_CHAIN                     0
# 4                TX:AGRC:INC_CONSERVATION_AGRICULTURE                     0
# ..                                                ...                   ...
# 69  TX:AGRC:DEC_CH4_RICE|TX:AGRC:DEC_EXPORTS|TX:AG...                     0
# 70  TX:LSMM:INC_MANAGEMENT_POULTRY_STRATEGY_NDC|TX...                     0
# 71  TX:WASO:INC_LANDFILLING_STRATEGY_NZ|TX:LSMM:IN...                     0
# 72  TX:AGRC:INC_PRODUCTIVITY_STRATEGY_BAU|TX:LVST:...                     0
# 73  TX:LVST:INC_PRODUCTIVITY_STRATEGY_NDC_2|TX:WAS...                     0
#
# [74 rows x 6 columns]

# %% [markdown]
# ##  Build our templates
# - let's use the default variable groupings for LHS

# %%
# Building excel templates, make sure to include the strategies ids in the strategies attribute as well as the baseline (0)
# df_vargroups = examples("variable_trajectory_group_specification")

strategies.build_strategies_to_templates(
    # df_trajgroup = df_vargroups,
    # include_simplex_group_as_trajgroup = True,
    strategies = strategies_to_run,
)
# Out:
# 0

# %% [markdown]
# # Finally, load SISEPUEDE so that we can run it

# %%
import sisepuede as si
# timestamp_str = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
ssp = si.SISEPUEDE(
    "calibrated",
    db_type = "csv",
    #id_str = f"sisepuede_run_2025-07-28T12:30:52.790396",
    initialize_as_dummy = not(energy_model_flag), # no connection to Julia is initialized if set to True
    regions = [country_name],
    strategies = strategies,
    # try_exogenous_xl_types_in_variable_specification = True,
    attribute_time_period = cdn._ATTRIBUTE_TABLE_TIME_PERIOD
)
# Out:
# 2025-08-08 15:35:27,897 - INFO - Successfully initialized SISEPUEDEFileStructure.
# 2025-08-08 15:35:27,898 - WARNING - Missing key dict_dimensional_keys: key time_series not found. Tables that rely on the time_series will not have index checking.
# 2025-08-08 15:35:27,898 - INFO - 	Setting export engine to 'csv'.
# 2025-08-08 15:35:27,898 - WARNING - No index fields defined. Index field values will not be checked when writing to tables.
# 2025-08-08 15:35:27,898 - INFO - Successfully instantiated table ANALYSIS_METADATA
# 2025-08-08 15:35:27,899 - WARNING - No index fields found in ATTRIBUTE_DESIGN. Initializing index fields.
# 2025-08-08 15:35:27,899 - INFO - Successfully instantiated table ATTRIBUTE_DESIGN
# 2025-08-08 15:35:27,899 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES. Initializing index fields.
# 2025-08-08 15:35:27,899 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES
# 2025-08-08 15:35:27,900 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS. Initializing index fields.
# 2025-08-08 15:35:27,900 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS
# 2025-08-08 15:35:27,900 - WARNING - No index fields found in ATTRIBUTE_PRIMARY. Initializing index fields.
# 2025-08-08 15:35:27,900 - INFO - Successfully instantiated table ATTRIBUTE_PRIMARY
# 2025-08-08 15:35:27,900 - WARNING - No index fields found in ATTRIBUTE_STRATEGY. Initializing index fields.
# 2025-08-08 15:35:27,901 - INFO - Successfully instantiated table ATTRIBUTE_STRATEGY
# 2025-08-08 15:35:27,901 - WARNING - No index fields found in MODEL_BASE_INPUT_DATABASE. Initializing index fields.
# 2025-08-08 15:35:27,901 - INFO - Successfully instantiated table MODEL_BASE_INPUT_DATABASE
# 2025-08-08 15:35:27,901 - WARNING - No index fields found in MODEL_INPUT. Initializing index fields.
# 2025-08-08 15:35:27,901 - INFO - Successfully instantiated table MODEL_INPUT
# 2025-08-08 15:35:27,902 - WARNING - No index fields found in MODEL_OUTPUT. Initializing index fields.
# 2025-08-08 15:35:27,902 - INFO - Successfully instantiated table MODEL_OUTPUT
# 2025-08-08 15:35:27,902 - INFO - SISEPUEDEOutputDatabase successfully initialized IterativeDatabase.
# 2025-08-08 15:35:27,902 - INFO - Successfully initialized database with:
# 	type:	csv
# 	analysis id:	sisepuede_run_2025-08-08T15:35:27.633266
# 	fp_base_output:	/opt/miniconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/sisepuede/out/sisepuede_run_2025-08-08T15;35;27.633266/sisepuede_run_2025-08-08T15;35;27.633266_output_database
# 2025-08-08 15:35:27,902 - INFO - Running SISEPUEDE under template data mode 'calibrated'.
# 2025-08-08 15:35:27,903 - INFO - Initializing BaseInputDatabase
# yay
# 2025-08-08 15:35:28,504 - INFO - Initializing FutureTrajectories
# 2025-08-08 15:35:29,985 - INFO - Instantiating 1738 sampling units.
# 2025-08-08 15:35:29,994 - INFO - Iteration 0 complete.
# 2025-08-08 15:35:32,169 - INFO - Iteration 250 complete.
# 2025-08-08 15:35:33,670 - INFO - Iteration 500 complete.
# 2025-08-08 15:35:35,103 - INFO - Iteration 750 complete.
# 2025-08-08 15:35:36,430 - INFO - Iteration 1000 complete.
# 2025-08-08 15:35:37,837 - INFO - Iteration 1250 complete.
# 2025-08-08 15:35:39,158 - INFO - Iteration 1500 complete.
# 2025-08-08 15:35:40,507 - INFO - 	1738 sampling units complete in 10.52 seconds.
# 2025-08-08 15:35:40,511 - INFO - 	FutureTrajectories for 'uganda' complete.
# 2025-08-08 15:35:40,512 - INFO - Initializing LHSDesign
# 2025-08-08 15:35:40,512 - INFO - LHSDesign.fields_factors_l reset successful.
# 2025-08-08 15:35:40,512 - INFO - LHSDesign.fields_factors_x reset successful.
# 2025-08-08 15:35:40,528 - INFO - 	LHSDesign for region 'uganda' complete.
# 2025-08-08 15:35:40,528 - INFO - Generating primary keys (values of primary_id)...
# 2025-08-08 15:35:40,528 - INFO - Successfully initialized SISEPUEDEExperimentalManager.
# 2025-08-08 15:35:40,529 - INFO - Successfully initialized NemoMod temporary database path as /opt/miniconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/sisepuede/tmp/nemomod_intermediate_database.sqlite.
# 2025-08-08 15:35:40,529 - INFO - Set Julia directory for modules and environment to '/opt/miniconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/sisepuede/julia'.
# 2025-08-08 15:35:40,570 - INFO - Successfully read NemoMod input table data from /opt/miniconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/sisepuede/ref/nemo_mod/SpecifiedDemandProfile.csv
# 2025-08-08 15:35:40,573 - INFO - Successfully read NemoMod input table data from /opt/miniconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/sisepuede/ref/nemo_mod/AvailabilityFactor.csv
# 2025-08-08 15:35:40,613 - INFO - Importing Julia...
# WARNING: replacing module SISEPUEDEPJSF.
# 2025-08-08 15:35:40,631 - INFO - Successfully initialized JuMP optimizer from solver module HiGHS.
# 2025-08-08 15:35:40,642 - INFO - Successfully initialized SISEPUEDEModels.
# 2025-08-08 15:35:40,646 - INFO - Table ANALYSIS_METADATA successfully written to /opt/miniconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/sisepuede/out/sisepuede_run_2025-08-08T15;35;27.633266/sisepuede_run_2025-08-08T15;35;27.633266_output_database/ANALYSIS_METADATA.csv.
# 2025-08-08 15:35:40,647 - INFO - Table ATTRIBUTE_DESIGN successfully written to /opt/miniconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/sisepuede/out/sisepuede_run_2025-08-08T15;35;27.633266/sisepuede_run_2025-08-08T15;35;27.633266_output_database/ATTRIBUTE_DESIGN.csv.
# 2025-08-08 15:35:40,648 - INFO - Table ATTRIBUTE_STRATEGY successfully written to /opt/miniconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/sisepuede/out/sisepuede_run_2025-08-08T15;35;27.633266/sisepuede_run_2025-08-08T15;35;27.633266_output_database/ATTRIBUTE_STRATEGY.csv.
# 2025-08-08 15:35:40,726 - INFO - Table MODEL_BASE_INPUT_DATABASE successfully written to /opt/miniconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/sisepuede/out/sisepuede_run_2025-08-08T15;35;27.633266/sisepuede_run_2025-08-08T15;35;27.633266_output_database/MODEL_BASE_INPUT_DATABASE.csv.

# %%
df_baseline = strategies.get_strategy(0)
df_baseline = df_baseline()
df_baseline.tail()
# Out:
#     strategy_id  frac_agrc_nuts_cl1_temperate  yf_agrc_cereals_tonne_ha  \
# 51            0                      0.030468                  1.799328
# 52            0                      0.030468                  1.799328
# 53            0                      0.030468                  1.799328
# 54            0                      0.030468                  1.799328
# 55            0                      0.030468                  1.799328
#
#     frac_agrc_rice_cl2_wet  frac_agrc_cereals_cl1_tropical  \
# 51                0.988021                        0.969532
# 52                0.988021                        0.969532
# 53                0.988021                        0.969532
# 54                0.988021                        0.969532
# 55                0.988021                        0.969532
#
#     frac_agrc_tubers_cl1_tropical  frac_agrc_bevs_and_spices_cl2_wet  \
# 51                       0.969532                           0.988021
# 52                       0.969532                           0.988021
# 53                       0.969532                           0.988021
# 54                       0.969532                           0.988021
# 55                       0.969532                           0.988021
#
#     frac_agrc_tubers_cl2_wet  frac_frst_primary_cl1_temperate_nutrient_rich  \
# 51                  0.988021                                       0.015234
# 52                  0.988021                                       0.015234
# 53                  0.988021                                       0.015234
# 54                  0.988021                                       0.015234
# 55                  0.988021                                       0.015234
#
#     frac_lndu_grasslands_cl2_dry  ...  \
# 51                      0.011979  ...
# 52                      0.011979  ...
# 53                      0.011979  ...
# 54                      0.011979  ...
# 55                      0.011979  ...
#
#     consumpinit_inen_energy_tj_per_mmm_gdp_other_product_manufacturing  \
# 51                                          421.17941
# 52                                          421.17941
# 53                                          421.17941
# 54                                          421.17941
# 55                                          421.17941
#
#     cost_enfu_fuel_biofuels_usd_per_m3  cost_enfu_fuel_crude_usd_per_m3  \
# 51                          514.896802                       376.533219
# 52                          514.763063                       376.435418
# 53                          514.629358                       376.337643
# 54                          514.495688                       376.239893
# 55                          514.362053                       376.142168
#
#     cost_enfu_fuel_diesel_usd_per_m3  cost_enfu_fuel_furnace_gas_usd_per_m3  \
# 51                       1384.476201                           13562.507565
# 52                       1384.116597                           13558.984835
# 53                       1383.757086                           13555.463021
# 54                       1383.397669                           13551.942122
# 55                       1383.038345                           13548.422137
#
#     cost_enfu_fuel_gasoline_usd_per_m3  cost_enfu_fuel_kerosene_usd_per_m3  \
# 51                         1416.673954                          985.262080
# 52                         1416.305986                          985.006168
# 53                         1415.938115                          984.750322
# 54                         1415.570338                          984.494543
# 55                         1415.202658                          984.238830
#
#     cost_enfu_fuel_oil_usd_per_m3  time_period  region
# 51                     535.494962           51  uganda
# 52                     535.355872           52  uganda
# 53                     535.216819           53  uganda
# 54                     535.077801           54  uganda
# 55                     534.938820           55  uganda
#
# [5 rows x 2381 columns]

# %%
df_strategy = strategies.get_strategy(6006)
df_strategy = df_strategy()
df_strategy.tail()
# Out:
#     strategy_id  frac_agrc_nuts_cl1_temperate  yf_agrc_cereals_tonne_ha  \
# 51         6006                      0.030468                  2.130405
# 52         6006                      0.030468                  2.137602
# 53         6006                      0.030468                  2.144799
# 54         6006                      0.030468                  2.151996
# 55         6006                      0.030468                  2.159194
#
#     frac_agrc_rice_cl2_wet  frac_agrc_cereals_cl1_tropical  \
# 51                0.988021                        0.969532
# 52                0.988021                        0.969532
# 53                0.988021                        0.969532
# 54                0.988021                        0.969532
# 55                0.988021                        0.969532
#
#     frac_agrc_tubers_cl1_tropical  frac_agrc_bevs_and_spices_cl2_wet  \
# 51                       0.969532                           0.988021
# 52                       0.969532                           0.988021
# 53                       0.969532                           0.988021
# 54                       0.969532                           0.988021
# 55                       0.969532                           0.988021
#
#     frac_agrc_tubers_cl2_wet  frac_frst_primary_cl1_temperate_nutrient_rich  \
# 51                  0.988021                                       0.015234
# 52                  0.988021                                       0.015234
# 53                  0.988021                                       0.015234
# 54                  0.988021                                       0.015234
# 55                  0.988021                                       0.015234
#
#     frac_lndu_grasslands_cl2_dry  ...  \
# 51                      0.011979  ...
# 52                      0.011979  ...
# 53                      0.011979  ...
# 54                      0.011979  ...
# 55                      0.011979  ...
#
#     consumpinit_inen_energy_tj_per_mmm_gdp_other_product_manufacturing  \
# 51                                          421.17941
# 52                                          421.17941
# 53                                          421.17941
# 54                                          421.17941
# 55                                          421.17941
#
#     cost_enfu_fuel_biofuels_usd_per_m3  cost_enfu_fuel_crude_usd_per_m3  \
# 51                          514.896802                       376.533219
# 52                          514.763063                       376.435418
# 53                          514.629358                       376.337643
# 54                          514.495688                       376.239893
# 55                          514.362053                       376.142168
#
#     cost_enfu_fuel_diesel_usd_per_m3  cost_enfu_fuel_furnace_gas_usd_per_m3  \
# 51                       1384.476201                           13562.507565
# 52                       1384.116597                           13558.984835
# 53                       1383.757086                           13555.463021
# 54                       1383.397669                           13551.942122
# 55                       1383.038345                           13548.422137
#
#     cost_enfu_fuel_gasoline_usd_per_m3  cost_enfu_fuel_kerosene_usd_per_m3  \
# 51                         1416.673954                          985.262080
# 52                         1416.305986                          985.006168
# 53                         1415.938115                          984.750322
# 54                         1415.570338                          984.494543
# 55                         1415.202658                          984.238830
#
#     cost_enfu_fuel_oil_usd_per_m3  time_period  region
# 51                     535.494962           51  uganda
# 52                     535.355872           52  uganda
# 53                     535.216819           53  uganda
# 54                     535.077801           54  uganda
# 55                     534.938820           55  uganda
#
# [5 rows x 2381 columns]

# %%
df_out_baseline = ssp.models.project(df_input_data=df_baseline,
                   time_periods_run=list(range(16)))

df_out_strategy = ssp.models.project(df_input_data=df_strategy,
                   time_periods_run=list(range(16)))
# Out:
# 2025-08-08 15:37:00,138 - INFO - Running AFOLU model
# 2025-08-08 15:37:00,255 - INFO - AFOLU model run successfully completed
# 2025-08-08 15:37:00,255 - INFO - Running CircularEconomy model
# 2025-08-08 15:37:00,277 - INFO - CircularEconomy model run successfully completed
# 2025-08-08 15:37:00,277 - INFO - Running IPPU model
# 2025-08-08 15:37:00,309 - INFO - IPPU model run successfully completed
# 2025-08-08 15:37:00,310 - INFO - Running Energy model (EnergyConsumption without Fugitive Emissions)
# 2025-08-08 15:37:00,319 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2025-08-08 15:37:00,358 - INFO - EnergyConsumption without Fugitive Emissions model run successfully completed
# 2025-08-08 15:37:00,359 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2025-08-08 15:37:00,383 - INFO - 	Path to temporary NemoMod database '/opt/miniconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/sisepuede/tmp/nemomod_intermediate_database.sqlite' not found. Creating...
# 2025-08-Aug 15:37:00.610 Opened SQLite database at /opt/miniconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/sisepuede/tmp/nemomod_intermediate_database.sqlite.
# 2025-08-Aug 15:37:00.742 Added NEMO structure to SQLite database at /opt/miniconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/sisepuede/tmp/nemomod_intermediate_database.sqlite.
# 2025-08-Aug 15:37:07.005 Started modeling scenario. NEMO version = 2.0.0, solver = HiGHS.
# ┌ Warning: Model period emission limits (ModelPeriodEmissionLimit parameter) are not enforced when modeling selected years.
# └ @ NemoMod ~/.julia/packages/NemoMod/p49Bn/src/scenario_calculation.jl:6112
# 2025-08-08 15:37:26,872 - INFO - NemoMod ran successfully with the following status: OPTIMAL
# 2025-08-08 15:37:26,880 - INFO - EnergyProduction model run successfully completed
# 2025-08-08 15:37:26,880 - INFO - Running Energy (Fugitive Emissions)
# 2025-08-08 15:37:26,898 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2025-08-08 15:37:26,898 - INFO - Appending Socioeconomic outputs
# 2025-08-08 15:37:26,903 - INFO - Socioeconomic outputs successfully appended.
# 2025-08-08 15:37:26,904 - INFO - Running AFOLU model
# 2025-08-Aug 15:37:26.793 Finished modeling scenario.
# 2025-08-08 15:37:27,014 - INFO - AFOLU model run successfully completed
# 2025-08-08 15:37:27,014 - INFO - Running CircularEconomy model
# 2025-08-08 15:37:27,037 - INFO - CircularEconomy model run successfully completed
# 2025-08-08 15:37:27,037 - INFO - Running IPPU model
# 2025-08-08 15:37:27,067 - INFO - IPPU model run successfully completed
# 2025-08-08 15:37:27,068 - INFO - Running Energy model (EnergyConsumption without Fugitive Emissions)
# 2025-08-08 15:37:27,077 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2025-08-08 15:37:27,117 - INFO - EnergyConsumption without Fugitive Emissions model run successfully completed
# 2025-08-08 15:37:27,118 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2025-08-Aug 15:37:27.900 Started modeling scenario. NEMO version = 2.0.0, solver = HiGHS.
# ┌ Warning: Model period emission limits (ModelPeriodEmissionLimit parameter) are not enforced when modeling selected years.
# └ @ NemoMod ~/.julia/packages/NemoMod/p49Bn/src/scenario_calculation.jl:6112
# 2025-08-08 15:37:39,274 - INFO - NemoMod ran successfully with the following status: OPTIMAL
# 2025-08-08 15:37:39,280 - INFO - EnergyProduction model run successfully completed
# 2025-08-08 15:37:39,281 - INFO - Running Energy (Fugitive Emissions)
# 2025-08-08 15:37:39,299 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2025-08-08 15:37:39,299 - INFO - Appending Socioeconomic outputs
# 2025-08-08 15:37:39,303 - INFO - Socioeconomic outputs successfully appended.
# 2025-08-Aug 15:37:39.208 Finished modeling scenario.

# %%
# not(energy_model_flag)

# %%
# # This runs the model, make sure you edit key_stretegy with the strategy ids you want to execute include baseline (0)
# dict_scens = {
#     ssp.key_design: [0],
#     ssp.key_future: [0],
#     ssp.key_strategy: strategies_to_run,
# }

# ssp.project_scenarios(
#     dict_scens,
#     save_inputs = True,
#     include_electricity_in_energy = energy_model_flag
# )

# %%
# # Read input and output files
# df_out = ssp.read_output(None)
# df_in = ssp.read_input(None)

# %%
# df_out.head()

# %%
def plot_field_stack(
    df,
    fields,
    dict_format,
    time_col="time_period",
    primary_id=None,
    figsize=(18, 8),
    legend_loc='upper right',
    legend_bbox=(1.1, 1),
    ylabel="MT Emissions CO2e",
    xlabel="Time Period",
    title=None,
):
    """
    Plots a stack plot of the selected fields for a given primary_id.

    Args:
        df (pd.DataFrame): DataFrame containing output data.
        fields (list): List of column names to plot.
        dict_format (dict): Formatting dictionary for colors.
        time_col (str): Name of the time column.
        primary_id (int): Value of primary_id to filter.
        figsize (tuple): Figure size.
        legend_loc (str): Legend location.
        legend_bbox (tuple): Legend bbox_to_anchor.
        ylabel (str): Y-axis label.
        xlabel (str): X-axis label.
        title (str): Plot title.
    """
    fig, ax = plt.subplots(figsize=figsize)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    if title:
        ax.set_title(title)

    if primary_id is not None:
        df_plot = df[df[ssp.key_primary].isin([primary_id])]
    else:
        df_plot = df

    fig, ax = spu.plot_stack(
        df_plot,
        fields,
        dict_formatting=dict_format,
        field_x=time_col,
        figtuple=(fig, ax),
    )

    ax.legend(loc=legend_loc, bbox_to_anchor=legend_bbox, title="Fields")
    plt.show()

# %%
# Define the fields to plot and the formatting dictionary
subsector_emission_fields = matt.get_all_subsector_emission_total_fields()

dict_format = dict(
    (k, {"color": v}) for (k, v) in
    matt.get_subsector_color_map().items()
)

# %%
# run_primary_ids = df_out.primary_id.unique()
# run_primary_ids

# %%
# Plot the emissions stack for the primary_id 0 (which is the baseline)

plot_field_stack(
    df_out_baseline,
    subsector_emission_fields,
    dict_format,
    title=f"Emissions Stack Plot Primary ID"
)

# %%
plot_field_stack(
    df_out_strategy,
    subsector_emission_fields,
    dict_format,
    title=f"Emissions Stack Plot Primary ID"
)

# %% [markdown]
# ## Evaluate mitigation against baseline

# %%
subsector_emission_fields
# Out:
# ['emission_co2e_subsector_total_agrc',
#  'emission_co2e_subsector_total_frst',
#  'emission_co2e_subsector_total_lndu',
#  'emission_co2e_subsector_total_lsmm',
#  'emission_co2e_subsector_total_lvst',
#  'emission_co2e_subsector_total_soil',
#  'emission_co2e_subsector_total_waso',
#  'emission_co2e_subsector_total_trww',
#  'emission_co2e_subsector_total_ccsq',
#  'emission_co2e_subsector_total_entc',
#  'emission_co2e_subsector_total_fgtv',
#  'emission_co2e_subsector_total_inen',
#  'emission_co2e_subsector_total_scoe',
#  'emission_co2e_subsector_total_trns',
#  'emission_co2e_subsector_total_ippu']

# %%
def filter_and_sum_emissions(df, time_period, emission_fields):
    """
    Filter the DataFrame for a specific time period, sum emissions across specified fields,
    and drop those fields from the result.

    Args:
        df (pd.DataFrame): Input DataFrame.
        time_period (int): Time period to filter on.
        emission_fields (list): List of emission field names to sum.

    Returns:
        pd.DataFrame: Filtered DataFrame with 'total_emissions' column.
    """

    afolu_fields = [
        "emission_co2e_subsector_total_agrc",
        "emission_co2e_subsector_total_frst",
        "emission_co2e_subsector_total_lndu",
        "emission_co2e_subsector_total_lsmm",
        "emission_co2e_subsector_total_lvst",
        "emission_co2e_subsector_total_soil",    
        ]
    
    energy_fields = [
        "emission_co2e_subsector_total_entc",
        "emission_co2e_subsector_total_scoe",
        "emission_co2e_subsector_total_inen",
        "emission_co2e_subsector_total_fgtv",
        "emission_co2e_subsector_total_ccsq",
    ]

    waste_fields = [
        "emission_co2e_subsector_total_waso",
        "emission_co2e_subsector_total_trww",
    ]

    transport_fields = [
        "emission_co2e_subsector_total_trns",
    ]

    ippu_fields = [
        "emission_co2e_subsector_total_ippu",
    ]

    df_filtered = df[df['time_period'] == time_period].reset_index(drop=True)
    df_filtered = df_filtered[emission_fields]
    df_filtered['total_emissions'] = df_filtered[emission_fields].sum(axis=1)
    df_filtered['afolu_emissions'] = df_filtered[afolu_fields].sum(axis=1)
    df_filtered['energy_emissions'] = df_filtered[energy_fields].sum(axis=1)
    df_filtered['waste_emissions'] = df_filtered[waste_fields].sum(axis=1)
    df_filtered['transport_emissions'] = df_filtered[transport_fields].sum(axis=1)
    df_filtered['ippu_emissions'] = df_filtered[ippu_fields].sum(axis=1)

    df_filtered = df_filtered.drop(columns=emission_fields)
    return df_filtered

# Example usage:
# df_out_filtered = filter_and_sum_emissions(df_out_baseline, 15, subsector_emission_fields)
# df_out_filtered.head()

# %%
df_out_baseline_filtered = filter_and_sum_emissions(df_out_baseline, 15, subsector_emission_fields)
df_out_strategy_filtered = filter_and_sum_emissions(df_out_strategy, 15, subsector_emission_fields)

# %%
df_out_baseline_filtered.head()
# Out:
#    total_emissions  afolu_emissions  energy_emissions  waste_emissions  \
# 0       234.626209        62.696874        115.504568         26.96285
#
#    transport_emissions  ippu_emissions
# 0             23.80561        5.656306

# %%
df_out_strategy_filtered
# Out:
#    total_emissions  afolu_emissions  energy_emissions  waste_emissions  \
# 0       187.051009        55.193421         81.782631        24.628645
#
#    transport_emissions  ippu_emissions
# 0            20.369423        5.076889

# %%
# Calculate mitigation for each column
mitigation = df_out_baseline_filtered.iloc[0] - df_out_strategy_filtered.iloc[0]

# Build comparison table
comparison = pd.DataFrame({
    'Baseline Emissions': df_out_baseline_filtered.iloc[0],
    'Strategy Emissions': df_out_strategy_filtered.iloc[0],
    'Mitigation': mitigation
})

# Optional: round for neatness
comparison = comparison.round(3)

comparison
# Out:
#                      Baseline Emissions  Strategy Emissions  Mitigation
# total_emissions                 234.626             187.051      47.575
# afolu_emissions                  62.697              55.193       7.503
# energy_emissions                115.505              81.783      33.722
# waste_emissions                  26.963              24.629       2.334
# transport_emissions              23.806              20.369       3.436
# ippu_emissions                    5.656               5.077       0.579

# %%
# NOTE: Temporal fix to save the output files
OUTPUT_FOLDER_PATH = RUN_OUTPUT_DIR_PATH.joinpath(ssp.id_fs_safe)
os.makedirs(OUTPUT_FOLDER_PATH, exist_ok=True)

# %%
df_out_baseline.to_csv(OUTPUT_FOLDER_PATH.joinpath("df_out_baseline.csv"), index=False)
df_out_strategy.to_csv(OUTPUT_FOLDER_PATH.joinpath("df_out_strategy.csv"), index=False)

# %% [markdown]
# # Export Wide File (Last Mandatory Step)

# %%
# all_primaries = sorted(list(df_out[ssp.key_primary].unique()))

# # build if unable to simply read the data frame
# if df_in is None:
#     df_in = []
     
#     for region in ssp.regions:
#         for primary in all_primaries: 
#             df_in_filt = ssp.generate_scenario_database_from_primary_key(primary)
#             df_in.append(df_in_filt.get(region))
    
#     df_in = pd.concat(df_in, axis = 0).reset_index(drop = True)




# df_export = pd.merge(
#     df_out,
#     df_in,
#     how = "left",
# )



# # check output directory 
# dir_pkg = os.path.join(
#     ssp.file_struct.dir_out, 
#     f"sisepuede_summary_results_run_{ssp.id_fs_safe}"
# )
# os.makedirs(dir_pkg) if not os.path.exists(dir_pkg) else None


# for tab in ["ATTRIBUTE_STRATEGY"]:
#     table_df = ssp.database.db.read_table(tab)
#     if table_df is not None:
#         table_df.to_csv(
#             os.path.join(dir_pkg, f"{tab}.csv"),
#             index=None,
#             encoding="UTF-8"
#         )
#     else:
#         print(f"Warning: Table {tab} returned None.")


# df_primary = (
#     ssp
#     .odpt_primary
#     .get_indexing_dataframe(
#         sorted(list(df_out[ssp.key_primary].unique()))
#     )
# )
    
# df_primary.to_csv(
#     os.path.join(dir_pkg, f"ATTRIBUTE_PRIMARY.csv"),
#     index = None,
#     encoding = "UTF-8"
# )

# df_export.to_csv(
#     os.path.join(dir_pkg, f"sisepuede_results_{ssp.id_fs_safe}_WIDE_INPUTS_OUTPUTS.csv"),
#     index = None,
#     encoding = "UTF-8"
# )

# %%
# Getting the directory where the outputs are stored
ssp.file_struct.dir_out

# %%
# RUN_ID_OUTPUT_DIR_PATH = os.path.join(
#     RUN_OUTPUT_DIR_PATH, 
#     ssp.id_fs_safe
# )

# os.makedirs(RUN_ID_OUTPUT_DIR_PATH, exist_ok=True)

# df_primary.to_csv(
#     os.path.join(RUN_ID_OUTPUT_DIR_PATH, "ATTRIBUTE_PRIMARY.csv"),
#     index = None,
#     encoding = "UTF-8"
# )

# df_export.to_csv(

    
#     os.path.join(RUN_ID_OUTPUT_DIR_PATH, f"{ssp.id_fs_safe}.csv"),
#     index = None,
#     encoding = "UTF-8"
# )

# for tab in ["ATTRIBUTE_STRATEGY"]:
#     table_df = ssp.database.db.read_table(tab)
#     if table_df is not None:
#         table_df.to_csv(
#             os.path.join(RUN_ID_OUTPUT_DIR_PATH, f"{tab}.csv"),
#             index=None,
#             encoding="UTF-8"
#         )
#     else:
#         logger.warning(f"Warning: Table {tab} returned None.")

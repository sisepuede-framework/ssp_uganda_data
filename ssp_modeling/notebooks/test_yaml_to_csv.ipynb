# %%
import pandas as pd
import os
import pathlib
from utils.yaml_to_csv import GenerateTransformationsReport

# %%
# Set up dir paths

CURR_DIR_PATH = pathlib.Path(os.getcwd())
SSP_MODELING_DIR_PATH = CURR_DIR_PATH.parent
TRANSFORMATIONS_DIR_PATH = SSP_MODELING_DIR_PATH.joinpath("transformations")
REPORT_OUTPUT_DIR_PATH = CURR_DIR_PATH.joinpath("reports")

# %%
# make sure report output dir exists
os.makedirs(REPORT_OUTPUT_DIR_PATH, exist_ok=True)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
gtr = GenerateTransformationsReport()

# %% [markdown]
# ## Generate default transfromations report df

# %%
default_values_df = gtr.collect_transformations_params(
    folder_path=TRANSFORMATIONS_DIR_PATH
)

default_values_df.head()
# Out:
# /Users/tony/Documents/sisepuede_modeling/ssp_uganda_data/ssp_modeling/notebooks/utils/yaml_to_csv.py:218: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.reindex(columns=col_order).replace({None: np.nan})
#                  transformation_code     categories  \
# 0                   TX:IPPU:DEC_HFCS            NaN
# 1        TX:TRNS:SHIFT_FUEL_MARITIME  [water_borne]
# 2                 TX:ENTC:DEC_LOSSES            NaN
# 3      TX:ENTC:TARGET_CLEAN_HYDROGEN            NaN
# 4  TX:WASO:INC_ANAEROBIC_AND_COMPOST            NaN
#
#    categories_entc_max_investment_ramp  categories_entc_renewable  \
# 0                                  NaN                        NaN
# 1                                  NaN                        NaN
# 2                                  NaN                        NaN
# 3                                  NaN                        NaN
# 4                                  NaN                        NaN
#
#   categories_out  categories_source  categories_target  \
# 0            NaN                NaN                NaN
# 1            NaN                NaN                NaN
# 2            NaN                NaN                NaN
# 3            NaN                NaN                NaN
# 4            NaN                NaN                NaN
#
#   cats_inflow_restriction  dict_allocation_fuels_target dict_categories_out  \
# 0                     NaN                           NaN                 NaN
# 1                     NaN                           NaN                 NaN
# 2                     NaN                           NaN                 NaN
# 3                     NaN                           NaN                 NaN
# 4                     NaN                           NaN                 NaN
#
#    ...  magnitude_biogas  magnitude_burned  magnitude_compost  \
# 0  ...               NaN               NaN                NaN
# 1  ...               NaN               NaN                NaN
# 2  ...               NaN               NaN                NaN
# 3  ...               NaN               NaN                NaN
# 4  ...             0.475               NaN              0.475
#
#   magnitude_red_meat  magnitude_removed  magnitude_type  min_loss  \
# 0                NaN                NaN             NaN       NaN
# 1                NaN                NaN             NaN       NaN
# 2                NaN                NaN     final_value      0.02
# 3                NaN                NaN             NaN       NaN
# 4                NaN                NaN             NaN       NaN
#
#    scale_non_renewables_to_match_surplus_msp  vec_cats_lvst  \
# 0                                        NaN            NaN
# 1                                        NaN            NaN
# 2                                        NaN            NaN
# 3                                        NaN            NaN
# 4                                        NaN            NaN
#
#    vec_implementation_ramp
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
#
# [5 rows x 35 columns]

# %%
default_values_df.tail()
# Out:
#                  transformation_code categories  \
# 61                TX:IPPU:DEC_DEMAND        NaN
# 62                   TX:IPPU:DEC_N2O        NaN
# 63                      TX:LNDU:PLUR        NaN
# 64  TX:SCOE:INC_EFFICIENCY_APPLIANCE        NaN
# 65           TX:SCOE:SHIFT_FUEL_HEAT        NaN
#
#     categories_entc_max_investment_ramp  categories_entc_renewable  \
# 61                                  NaN                        NaN
# 62                                  NaN                        NaN
# 63                                  NaN                        NaN
# 64                                  NaN                        NaN
# 65                                  NaN                        NaN
#
#    categories_out  categories_source  categories_target  \
# 61            NaN                NaN                NaN
# 62            NaN                NaN                NaN
# 63            NaN                NaN                NaN
# 64            NaN                NaN                NaN
# 65            NaN                NaN                NaN
#
#    cats_inflow_restriction  dict_allocation_fuels_target dict_categories_out  \
# 61                     NaN                           NaN                 NaN
# 62                     NaN                           NaN                 NaN
# 63                     NaN                           NaN                 NaN
# 64                     NaN                           NaN                 NaN
# 65                     NaN                           NaN                 NaN
#
#     ...  magnitude_biogas  magnitude_burned  magnitude_compost  \
# 61  ...               NaN               NaN                NaN
# 62  ...               NaN               NaN                NaN
# 63  ...               NaN               NaN                NaN
# 64  ...               NaN               NaN                NaN
# 65  ...               NaN               NaN                NaN
#
#    magnitude_red_meat  magnitude_removed  magnitude_type  min_loss  \
# 61                NaN                NaN             NaN       NaN
# 62                NaN                NaN             NaN       NaN
# 63                NaN                NaN             NaN       NaN
# 64                NaN                NaN             NaN       NaN
# 65                NaN                NaN             NaN       NaN
#
#     scale_non_renewables_to_match_surplus_msp  vec_cats_lvst  \
# 61                                        NaN            NaN
# 62                                        NaN            NaN
# 63                                        NaN            NaN
# 64                                        NaN            NaN
# 65                                        NaN            NaN
#
#     vec_implementation_ramp
# 61                      NaN
# 62                      NaN
# 63                      NaN
# 64                      NaN
# 65                      NaN
#
# [5 rows x 35 columns]

# %%
# check for duplicates
duplicates = default_values_df[default_values_df.duplicated(subset=["transformation_code"], keep=False)]
if not duplicates.empty:
    print("Warning: Duplicate transformation codes found:")
else:
    print("No duplicate transformation codes found.")
# Out:
# Warning: Duplicate transformation codes found:

# %%
# drop duplicates and keep the first occurrence
default_values_df = default_values_df.drop_duplicates(subset=["transformation_code"], keep="first")

# %%
default_values_df_only_magnitude = default_values_df[["transformation_code", "magnitude"]].copy()
default_values_df_only_magnitude
# Out:
#                     transformation_code  magnitude
# 0                      TX:IPPU:DEC_HFCS       0.10
# 1           TX:TRNS:SHIFT_FUEL_MARITIME       0.70
# 2                    TX:ENTC:DEC_LOSSES       0.06
# 3         TX:ENTC:TARGET_CLEAN_HYDROGEN       0.95
# 4     TX:WASO:INC_ANAEROBIC_AND_COMPOST        NaN
# ..                                  ...        ...
# 59   TX:LSMM:INC_MANAGEMENT_CATTLE_PIGS        NaN
# 60  TX:TRNS:INC_EFFICIENCY_NON_ELECTRIC       0.25
# 61                   TX:IPPU:DEC_DEMAND       0.30
# 62                      TX:IPPU:DEC_N2O       0.10
# 63                         TX:LNDU:PLUR       0.50
#
# [64 rows x 2 columns]

# %% [markdown]
# ## Generate presence matrix for custom strategies
#
# This matrix will tell us which transformation are being used in our custom strategies

# %%
suffixes = ["NDC_2", "NZ", ]
cols = [f"strategy_{s}" for s in suffixes]

presence_df = gtr.build_strategy_presence_from_csv(
    csv_path=TRANSFORMATIONS_DIR_PATH / "strategy_definitions.csv",
    strategy_suffixes=suffixes,
    folder_path_for_defaults=TRANSFORMATIONS_DIR_PATH,
)

# be explicit & avoid chained assignment
presence_df = presence_df.copy()
presence_df[cols] = presence_df[cols].astype("Int8")   # or .astype(int)
presence_df
# Out:
#                      transformation_code  strategy_NDC_2  strategy_NZ
# 0                   TX:AGRC:DEC_CH4_RICE               0            1
# 1                    TX:AGRC:DEC_EXPORTS               0            1
# 2        TX:AGRC:DEC_LOSSES_SUPPLY_CHAIN               0            1
# 3   TX:AGRC:INC_CONSERVATION_AGRICULTURE               1            1
# 4               TX:AGRC:INC_PRODUCTIVITY               1            1
# ..                                   ...             ...          ...
# 59            TX:WASO:INC_CAPTURE_BIOGAS               1            1
# 60        TX:WASO:INC_ENERGY_FROM_BIOGAS               0            1
# 61  TX:WASO:INC_ENERGY_FROM_INCINERATION               0            1
# 62               TX:WASO:INC_LANDFILLING               1            1
# 63                 TX:WASO:INC_RECYCLING               1            1
#
# [64 rows x 3 columns]

# %%
# check for duplicates
duplicates = presence_df[presence_df.duplicated(subset=["transformation_code"], keep=False)]
if not duplicates.empty:
    print("Warning: Duplicate transformation codes found:")
    print(duplicates)
else:
    print("No duplicate transformation codes found.")
# Out:
# No duplicate transformation codes found.

# %% [markdown]
# ## Generate custom strategies transformation parameters report

# %%
strategy_params_df = gtr.collect_strategy_transformations_params(
    folder_path=TRANSFORMATIONS_DIR_PATH,
    strategy_suffixes=["NDC_2", "NZ"],
    recursive=True,
    include_file_path=False,       # optional traceability
    require_tx_prefix=True,
)

# %%
strategy_params_df.head()
# Out:
#    strategy_name                                transformation_code  \
# 49         NDC_2  TX:AGRC:INC_CONSERVATION_AGRICULTURE_STRATEGY_...
# 13         NDC_2            TX:AGRC:INC_PRODUCTIVITY_STRATEGY_NDC_2
# 17         NDC_2                  TX:ENTC:DEC_LOSSES_STRATEGY_NDC_2
# 40         NDC_2       TX:ENTC:TARGET_RENEWABLE_ELEC_STRATEGY_NDC_2
# 29         NDC_2       TX:INEN:INC_EFFICIENCY_ENERGY_STRATEGY_NDC_2
#
#              default_transformation_code categories  \
# 49  TX:AGRC:INC_CONSERVATION_AGRICULTURE        NaN
# 13              TX:AGRC:INC_PRODUCTIVITY        NaN
# 17                    TX:ENTC:DEC_LOSSES        NaN
# 40         TX:ENTC:TARGET_RENEWABLE_ELEC        NaN
# 29         TX:INEN:INC_EFFICIENCY_ENERGY        NaN
#
#     categories_entc_max_investment_ramp  categories_entc_renewable  \
# 49                                  NaN                        NaN
# 13                                  NaN                        NaN
# 17                                  NaN                        NaN
# 40                                  NaN                        NaN
# 29                                  NaN                        NaN
#
#    categories_out  categories_source  categories_target  \
# 49            NaN                NaN                NaN
# 13            NaN                NaN                NaN
# 17            NaN                NaN                NaN
# 40            NaN                NaN                NaN
# 29            NaN                NaN                NaN
#
#    cats_inflow_restriction  ...  magnitude magnitude_biogas  magnitude_burned  \
# 49                     NaN  ...        NaN              NaN               0.0
# 13                     NaN  ...      0.200              NaN               NaN
# 17                     NaN  ...      0.060              NaN               NaN
# 40                     NaN  ...      0.950              NaN               NaN
# 29                     NaN  ...      0.003              NaN               NaN
#
#     magnitude_compost magnitude_removed  magnitude_type  min_loss  \
# 49                NaN               0.5             NaN       NaN
# 13                NaN               NaN             NaN       NaN
# 17                NaN               NaN     final_value      0.02
# 40                NaN               NaN             NaN       NaN
# 29                NaN               NaN             NaN       NaN
#
#     scale_non_renewables_to_match_surplus_msp  vec_cats_lvst  \
# 49                                        NaN            NaN
# 13                                        NaN            NaN
# 17                                        NaN            NaN
# 40                                      False            NaN
# 29                                        NaN            NaN
#
#               vec_implementation_ramp
# 49  {'tp_0_ramp': 5, 'n_tp_ramp': 10}
# 13  {'tp_0_ramp': 5, 'n_tp_ramp': 10}
# 17                   {'tp_0_ramp': 5}
# 40                   {'tp_0_ramp': 5}
# 29                   {'tp_0_ramp': 5}
#
# [5 rows x 34 columns]

# %%
# Drop duplicates and keep the first occurrence
strategy_params_df = strategy_params_df.drop_duplicates(subset=["transformation_code"], keep="first")

# %%
strategy_params_df_only_magnitude = strategy_params_df[["strategy_name", "transformation_code", "default_transformation_code", "magnitude"]].copy()
strategy_params_df_only_magnitude
# Out:
#    strategy_name                                transformation_code  \
# 49         NDC_2  TX:AGRC:INC_CONSERVATION_AGRICULTURE_STRATEGY_...
# 13         NDC_2            TX:AGRC:INC_PRODUCTIVITY_STRATEGY_NDC_2
# 17         NDC_2                  TX:ENTC:DEC_LOSSES_STRATEGY_NDC_2
# 40         NDC_2       TX:ENTC:TARGET_RENEWABLE_ELEC_STRATEGY_NDC_2
# 29         NDC_2       TX:INEN:INC_EFFICIENCY_ENERGY_STRATEGY_NDC_2
# ..           ...                                                ...
# 30            NZ             TX:WASO:INC_CAPTURE_BIOGAS_STRATEGY_NZ
# 14            NZ         TX:WASO:INC_ENERGY_FROM_BIOGAS_STRATEGY_NZ
# 70            NZ   TX:WASO:INC_ENERGY_FROM_INCINERATION_STRATEGY_NZ
# 2             NZ                TX:WASO:INC_LANDFILLING_STRATEGY_NZ
# 83            NZ                  TX:WASO:INC_RECYCLING_STRATEGY_NZ
#
#              default_transformation_code  magnitude
# 49  TX:AGRC:INC_CONSERVATION_AGRICULTURE        NaN
# 13              TX:AGRC:INC_PRODUCTIVITY      0.200
# 17                    TX:ENTC:DEC_LOSSES      0.060
# 40         TX:ENTC:TARGET_RENEWABLE_ELEC      0.950
# 29         TX:INEN:INC_EFFICIENCY_ENERGY      0.003
# ..                                   ...        ...
# 30            TX:WASO:INC_CAPTURE_BIOGAS      1.700
# 14        TX:WASO:INC_ENERGY_FROM_BIOGAS      1.700
# 70  TX:WASO:INC_ENERGY_FROM_INCINERATION      1.700
# 2                TX:WASO:INC_LANDFILLING      1.000
# 83                 TX:WASO:INC_RECYCLING      0.950
#
# [87 rows x 4 columns]

# %%
default_values_df_only_magnitude
# Out:
#                     transformation_code  magnitude
# 0                      TX:IPPU:DEC_HFCS       0.10
# 1           TX:TRNS:SHIFT_FUEL_MARITIME       0.70
# 2                    TX:ENTC:DEC_LOSSES       0.06
# 3         TX:ENTC:TARGET_CLEAN_HYDROGEN       0.95
# 4     TX:WASO:INC_ANAEROBIC_AND_COMPOST        NaN
# ..                                  ...        ...
# 59   TX:LSMM:INC_MANAGEMENT_CATTLE_PIGS        NaN
# 60  TX:TRNS:INC_EFFICIENCY_NON_ELECTRIC       0.25
# 61                   TX:IPPU:DEC_DEMAND       0.30
# 62                      TX:IPPU:DEC_N2O       0.10
# 63                         TX:LNDU:PLUR       0.50
#
# [64 rows x 2 columns]

# %%
strategy_params_df_only_magnitude = pd.merge(
    strategy_params_df_only_magnitude,
    default_values_df_only_magnitude,
    how="left",
    left_on="default_transformation_code",
    right_on="transformation_code",
    suffixes=("", "_default"),
)

strategy_params_df_only_magnitude
# Out:
#    strategy_name                                transformation_code  \
# 0          NDC_2  TX:AGRC:INC_CONSERVATION_AGRICULTURE_STRATEGY_...
# 1          NDC_2            TX:AGRC:INC_PRODUCTIVITY_STRATEGY_NDC_2
# 2          NDC_2                  TX:ENTC:DEC_LOSSES_STRATEGY_NDC_2
# 3          NDC_2       TX:ENTC:TARGET_RENEWABLE_ELEC_STRATEGY_NDC_2
# 4          NDC_2       TX:INEN:INC_EFFICIENCY_ENERGY_STRATEGY_NDC_2
# ..           ...                                                ...
# 82            NZ             TX:WASO:INC_CAPTURE_BIOGAS_STRATEGY_NZ
# 83            NZ         TX:WASO:INC_ENERGY_FROM_BIOGAS_STRATEGY_NZ
# 84            NZ   TX:WASO:INC_ENERGY_FROM_INCINERATION_STRATEGY_NZ
# 85            NZ                TX:WASO:INC_LANDFILLING_STRATEGY_NZ
# 86            NZ                  TX:WASO:INC_RECYCLING_STRATEGY_NZ
#
#              default_transformation_code  magnitude  \
# 0   TX:AGRC:INC_CONSERVATION_AGRICULTURE        NaN
# 1               TX:AGRC:INC_PRODUCTIVITY      0.200
# 2                     TX:ENTC:DEC_LOSSES      0.060
# 3          TX:ENTC:TARGET_RENEWABLE_ELEC      0.950
# 4          TX:INEN:INC_EFFICIENCY_ENERGY      0.003
# ..                                   ...        ...
# 82            TX:WASO:INC_CAPTURE_BIOGAS      1.700
# 83        TX:WASO:INC_ENERGY_FROM_BIOGAS      1.700
# 84  TX:WASO:INC_ENERGY_FROM_INCINERATION      1.700
# 85               TX:WASO:INC_LANDFILLING      1.000
# 86                 TX:WASO:INC_RECYCLING      0.950
#
#              transformation_code_default  magnitude_default
# 0   TX:AGRC:INC_CONSERVATION_AGRICULTURE                NaN
# 1               TX:AGRC:INC_PRODUCTIVITY               0.20
# 2                     TX:ENTC:DEC_LOSSES               0.06
# 3          TX:ENTC:TARGET_RENEWABLE_ELEC               0.95
# 4          TX:INEN:INC_EFFICIENCY_ENERGY               0.30
# ..                                   ...                ...
# 82            TX:WASO:INC_CAPTURE_BIOGAS               0.85
# 83        TX:WASO:INC_ENERGY_FROM_BIOGAS               0.85
# 84  TX:WASO:INC_ENERGY_FROM_INCINERATION               0.85
# 85               TX:WASO:INC_LANDFILLING               1.00
# 86                 TX:WASO:INC_RECYCLING               0.95
#
# [87 rows x 6 columns]

# %%
# check for duplicates
duplicates = strategy_params_df_only_magnitude[strategy_params_df_only_magnitude.duplicated(subset=["transformation_code"], keep=False)]
if not duplicates.empty:
    print("Warning: Duplicate transformation codes found:")
    print(duplicates)
else:
    print("No duplicate transformation codes found.")
# Out:
# No duplicate transformation codes found.

# %%
# Calculate the percentage change where 100% means the same magnitude, >100% means increase
strategy_params_df_only_magnitude["magnitude_multiplier"] = (
    strategy_params_df_only_magnitude["magnitude"] / strategy_params_df_only_magnitude["magnitude_default"]
)

strategy_params_df_only_magnitude
# Out:
#    strategy_name                                transformation_code  \
# 0          NDC_2  TX:AGRC:INC_CONSERVATION_AGRICULTURE_STRATEGY_...
# 1          NDC_2            TX:AGRC:INC_PRODUCTIVITY_STRATEGY_NDC_2
# 2          NDC_2                  TX:ENTC:DEC_LOSSES_STRATEGY_NDC_2
# 3          NDC_2       TX:ENTC:TARGET_RENEWABLE_ELEC_STRATEGY_NDC_2
# 4          NDC_2       TX:INEN:INC_EFFICIENCY_ENERGY_STRATEGY_NDC_2
# ..           ...                                                ...
# 82            NZ             TX:WASO:INC_CAPTURE_BIOGAS_STRATEGY_NZ
# 83            NZ         TX:WASO:INC_ENERGY_FROM_BIOGAS_STRATEGY_NZ
# 84            NZ   TX:WASO:INC_ENERGY_FROM_INCINERATION_STRATEGY_NZ
# 85            NZ                TX:WASO:INC_LANDFILLING_STRATEGY_NZ
# 86            NZ                  TX:WASO:INC_RECYCLING_STRATEGY_NZ
#
#              default_transformation_code  magnitude  \
# 0   TX:AGRC:INC_CONSERVATION_AGRICULTURE        NaN
# 1               TX:AGRC:INC_PRODUCTIVITY      0.200
# 2                     TX:ENTC:DEC_LOSSES      0.060
# 3          TX:ENTC:TARGET_RENEWABLE_ELEC      0.950
# 4          TX:INEN:INC_EFFICIENCY_ENERGY      0.003
# ..                                   ...        ...
# 82            TX:WASO:INC_CAPTURE_BIOGAS      1.700
# 83        TX:WASO:INC_ENERGY_FROM_BIOGAS      1.700
# 84  TX:WASO:INC_ENERGY_FROM_INCINERATION      1.700
# 85               TX:WASO:INC_LANDFILLING      1.000
# 86                 TX:WASO:INC_RECYCLING      0.950
#
#              transformation_code_default  magnitude_default  \
# 0   TX:AGRC:INC_CONSERVATION_AGRICULTURE                NaN
# 1               TX:AGRC:INC_PRODUCTIVITY               0.20
# 2                     TX:ENTC:DEC_LOSSES               0.06
# 3          TX:ENTC:TARGET_RENEWABLE_ELEC               0.95
# 4          TX:INEN:INC_EFFICIENCY_ENERGY               0.30
# ..                                   ...                ...
# 82            TX:WASO:INC_CAPTURE_BIOGAS               0.85
# 83        TX:WASO:INC_ENERGY_FROM_BIOGAS               0.85
# 84  TX:WASO:INC_ENERGY_FROM_INCINERATION               0.85
# 85               TX:WASO:INC_LANDFILLING               1.00
# 86                 TX:WASO:INC_RECYCLING               0.95
#
#     magnitude_multiplier
# 0                    NaN
# 1                   1.00
# 2                   1.00
# 3                   1.00
# 4                   0.01
# ..                   ...
# 82                  2.00
# 83                  2.00
# 84                  2.00
# 85                  1.00
# 86                  1.00
#
# [87 rows x 7 columns]

# %%
# drop transformation_code_default column
strategy_params_df_only_magnitude = strategy_params_df_only_magnitude.drop(columns=["transformation_code_default"])
strategy_params_df_only_magnitude
# Out:
#    strategy_name                                transformation_code  \
# 0          NDC_2  TX:AGRC:INC_CONSERVATION_AGRICULTURE_STRATEGY_...
# 1          NDC_2            TX:AGRC:INC_PRODUCTIVITY_STRATEGY_NDC_2
# 2          NDC_2                  TX:ENTC:DEC_LOSSES_STRATEGY_NDC_2
# 3          NDC_2       TX:ENTC:TARGET_RENEWABLE_ELEC_STRATEGY_NDC_2
# 4          NDC_2       TX:INEN:INC_EFFICIENCY_ENERGY_STRATEGY_NDC_2
# ..           ...                                                ...
# 82            NZ             TX:WASO:INC_CAPTURE_BIOGAS_STRATEGY_NZ
# 83            NZ         TX:WASO:INC_ENERGY_FROM_BIOGAS_STRATEGY_NZ
# 84            NZ   TX:WASO:INC_ENERGY_FROM_INCINERATION_STRATEGY_NZ
# 85            NZ                TX:WASO:INC_LANDFILLING_STRATEGY_NZ
# 86            NZ                  TX:WASO:INC_RECYCLING_STRATEGY_NZ
#
#              default_transformation_code  magnitude  magnitude_default  \
# 0   TX:AGRC:INC_CONSERVATION_AGRICULTURE        NaN                NaN
# 1               TX:AGRC:INC_PRODUCTIVITY      0.200               0.20
# 2                     TX:ENTC:DEC_LOSSES      0.060               0.06
# 3          TX:ENTC:TARGET_RENEWABLE_ELEC      0.950               0.95
# 4          TX:INEN:INC_EFFICIENCY_ENERGY      0.003               0.30
# ..                                   ...        ...                ...
# 82            TX:WASO:INC_CAPTURE_BIOGAS      1.700               0.85
# 83        TX:WASO:INC_ENERGY_FROM_BIOGAS      1.700               0.85
# 84  TX:WASO:INC_ENERGY_FROM_INCINERATION      1.700               0.85
# 85               TX:WASO:INC_LANDFILLING      1.000               1.00
# 86                 TX:WASO:INC_RECYCLING      0.950               0.95
#
#     magnitude_multiplier
# 0                    NaN
# 1                   1.00
# 2                   1.00
# 3                   1.00
# 4                   0.01
# ..                   ...
# 82                  2.00
# 83                  2.00
# 84                  2.00
# 85                  1.00
# 86                  1.00
#
# [87 rows x 6 columns]

# %% [markdown]
# ## Save complete report in an excel file

# %%
FILE_PATH = REPORT_OUTPUT_DIR_PATH.joinpath("ssp_uganda_transformations_report.xlsx")
overwrite_existing_file = False

if overwrite_existing_file or not FILE_PATH.exists():
    with pd.ExcelWriter(FILE_PATH, engine="openpyxl", mode="w") as xw:
        default_values_df.to_excel(xw, "DefaultTransformations", index=False)
        presence_df.to_excel(xw, "StrategyPresence", index=False)
        strategy_params_df.to_excel(xw, "StrategyParams", index=False)
        strategy_params_df_only_magnitude.to_excel(xw, "ParamsMagnitude", index=False)
else:
    print(f"File {FILE_PATH} already exists and overwrite_existing_file is False. File not saved.")
# Out:
# File /Users/tony/Documents/sisepuede_modeling/ssp_uganda_data/ssp_modeling/notebooks/reports/ssp_uganda_transformations_report.xlsx already exists and overwrite_existing_file is False. File not saved.

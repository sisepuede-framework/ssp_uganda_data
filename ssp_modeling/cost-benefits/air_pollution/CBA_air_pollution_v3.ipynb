# %%
# Load packages
from costs_benefits_ssp.cb_calculate import CostBenefits
import pandas as pd
import os
import pathlib
import numpy as np

# %%
# Define paths
SSP_PATH = pathlib.Path(os.getcwd()).parent.parent.as_posix()
SSP_RUN  = os.path.join(SSP_PATH, "ssp_run_output/sisepuede_summary_results_run_sisepuede_run_2026-04-01T14;29;26.355576/nwr")


CB_DEFAULT_DEFINITION_PATH = os.path.join(SSP_PATH,"cost-benefits/cb_cost_factors")
CB_DEFAULT_DEFINITION_FILE_PATH = os.path.join(CB_DEFAULT_DEFINITION_PATH, "cb_config_params.xlsx")

CB_OUTPUT = os.path.join(SSP_PATH, "Tableau/data")

# %%
CB_OUTPUT
# Out:
# '/Users/alexa/Projects/ssp_uganda_data/ssp_modeling/Tableau/data'

# %%
CB_DEFAULT_DEFINITION_PATH
# Out:
# '/Users/alexa/Projects/ssp_uganda_data/ssp_modeling/cost-benefits/cb_cost_factors'

# %%
# Load data
ssp_data = pd.read_csv(os.path.join(SSP_RUN, "uganda.csv"))
att_primary = pd.read_csv(os.path.join(SSP_RUN,"ATTRIBUTE_PRIMARY.csv"))
att_strategy = pd.read_csv(os.path.join(SSP_RUN,"ATTRIBUTE_STRATEGY.csv"))
strategy_code_base = "BASE"

# %%
att_primary
# Out:
#    primary_id  design_id  strategy_id  future_id
# 0           0          0            0          0
# 1      700070          0         6004          0
# 2      750075          0         6009          0
# 3      760076          0         6010          0
# 4      770077          0         6011          0
# 5      780078          0         6012          0

# %%
# Instantiate CostBenefits object
cb = CostBenefits(ssp_data, att_primary, att_strategy, strategy_code_base)

# The export_db_to_excel method saves the initial configuration of the cost tables to an excel file.
# Each sheet represents a table in the cost and benefit program database.
# If the Excel file name is not given, the file will be saved with the default name cb_config_params.xlsx on the current python session.

#cb.export_db_to_excel(CB_DEFAULT_DEFINITION_FILE_PATH)

# Once that the excel file has been updated, we can reload it in order to update the cost factors database
cb.load_cb_parameters(CB_DEFAULT_DEFINITION_FILE_PATH)
# Out:
# The TX TX:FRST:INCREASE_SEQUESTRATION_NZ is missing on AttTransformationCode
# The TX TX:LNDU:DEC_WETLAND_LOSS_NZ is missing on AttTransformationCode
# The TX TX:LNDU:SET_WETLANDS_MINIMUM_NZ is missing on AttTransformationCode
# The TX TX:SCOE:INC_EFFICIENCY_HEAT_NZ is missing on AttTransformationCode
# The TX TX:FRST:INCREASE_SEQUESTRATION_NDC_25 is missing on AttTransformationCode
# The TX TX:LNDU:DEC_WETLAND_LOSS_NDC_25 is missing on AttTransformationCode
# The TX TX:LNDU:SET_WETLANDS_MINIMUM_NDC_25 is missing on AttTransformationCode
# The TX TX:SCOE:INC_EFFICIENCY_HEAT_NDC_25 is missing on AttTransformationCode
# The TX TX:FRST:INCREASE_SEQUESTRATION_NDC_25 is missing on AttTransformationCode
# The TX TX:LNDU:DEC_WETLAND_LOSS_NDC_25 is missing on AttTransformationCode
# The TX TX:LNDU:SET_WETLANDS_MINIMUM_NDC_25 is missing on AttTransformationCode
# The TX TX:SCOE:INC_EFFICIENCY_HEAT_NDC_25 is missing on AttTransformationCode
# The TX TX:SCOE:INC_EFFICIENCY_HEAT_NDC_25 is missing on AttTransformationCode
# The TX TX:LNDU:DEC_WETLAND_LOSS_NDC_25 is missing on AttTransformationCode
# The TX TX:LNDU:SET_WETLANDS_MINIMUM_NDC_25 is missing on AttTransformationCode
# The TX TX:SCOE:INC_EFFICIENCY_HEAT_NDC_25 is missing on AttTransformationCode
# Cargamos configuración de archivo excel
# Se actualizó la base de datos

# %%
# Compute System Costs
results_system = cb.compute_system_cost_for_all_strategies()
# Out:
# ************************************
# *Strategy : PFLO:HBLE (0/5)
# ************************************
#
# ---------Costs for: cb:wali:technical_cost:sanitation:unimp_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:imp_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:safeman_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:unimp_urban.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:imp_urban.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:safeman_urban.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:omit_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:technical_cost:electricity:capex.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:technical_cost:electricity:transmission.
# La variable se evalúa en System Cost
# ---------Costs for: change_in_emissions.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:air_pollution:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:air_pollution:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:air_pollution:X:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lndu:ecosystem_services:forests:primary.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lndu:ecosystem_services:forests:secondary.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:freight_transport:aviation.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:freight_transport:rail.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:freight_transport:road_heavy.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:freight_transport:water_borne.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:biogas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:compost.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:incinerated.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:landfilled.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:open_dump.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:recycled.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:tertiary_aerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:tertiary_anaerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:primary.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:secondary_aerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:secondary_anaerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:untreated_with_sewerage.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:human_health:safe_sanitation:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:buffalo.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:cattle_dairy.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:cattle_nondairy.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:chickens.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:goats.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:horses.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:mules.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:pigs.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:sheep.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:bevs_and_spices.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:cereals.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:fibers.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:fruits.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:herbs.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:nuts.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:other_annual.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:other_woody_perennial.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:pulses.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:rice.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:sugar_cane.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:tubers.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:vegetables.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:waste_to_energy:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:fuel_cost:waste_to_energy_value:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ccsq:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:scoe:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ippu:air_pollution:X:cement.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:aviation.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:powered_bikes.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:public.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:rail_passenger.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:road_heavy_regional.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:road_light.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:env_pollution:open_dumping:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ippu:ippu_value:industrial_products:cement.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ippu:ippu_value:industrial_products:steel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ccsq:sector_specific:electricity_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:sector_specific:electricity_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:scoe:sector_specific:electricity_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:sector_specific:electricity_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_to_energy:incineration.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_to_energy:anaerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_to_energy:landfill.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:fuel_cost:waste_to_energy_value:anaerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:fuel_cost:waste_to_energy_value:landfill.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:air_pollution:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:air_pollution:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:air_pollution:X:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:congestion:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:congestion:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:congestion:X:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:congestion:X:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:biogas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:compost.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:incinerated.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:landfilled.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:open_dump.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:recycled.
# La variable se evalúa en System Cost
# ---------Costs for: cb:soil:technical_cost:agriculture_inputs:fertilizer.
# La variable se evalúa en System Cost
# ---------Costs for: cb:soil:land_pollution:N_leaching:fertilizer.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:biomass.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:coal.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:coke.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:X:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:road_safety:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:road_safety:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:road_safety:X:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:road_safety:X:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:water_pollution:wastewater_treatment:P.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:water_pollution:wastewater_treatment:N.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:water_pollution:wastewater_treatment:COD.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:water_pollution:wastewater_treatment:BOD.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lsmm:fuel_cost:waste_to_energy_value:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:ccsq:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:ccsq:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:ccsq:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:biogas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:biomass.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:coal.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:coke.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:hydrocarbon_gas_liquids.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:kerosene.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:nuclear.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:oil.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:other.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:waste.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:biomass.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:coal.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:coke.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:hydrocarbon_gas_liquids.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:kerosene.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:oil.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:biomass.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:coal.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:hydrocarbon_gas_liquids.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:kerosene.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:hydrocarbon_gas_liquids.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:kerosene.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:natural_gas.
# La variable se evalúa en System Cost
#
# ************************************
# *Strategy : PFLO:NDC_25 (1/5)
# ************************************
#
# ---------Costs for: cb:wali:technical_cost:sanitation:unimp_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:imp_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:safeman_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:unimp_urban.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:imp_urban.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:safeman_urban.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:omit_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:technical_cost:electricity:capex.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:technical_cost:electricity:transmission.
# La variable se evalúa en System Cost
# ---------Costs for: change_in_emissions.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:air_pollution:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:air_pollution:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:air_pollution:X:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lndu:ecosystem_services:forests:primary.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lndu:ecosystem_services:forests:secondary.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:freight_transport:aviation.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:freight_transport:rail.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:freight_transport:road_heavy.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:freight_transport:water_borne.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:biogas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:compost.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:incinerated.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:landfilled.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:open_dump.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:recycled.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:tertiary_aerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:tertiary_anaerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:primary.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:secondary_aerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:secondary_anaerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:untreated_with_sewerage.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:human_health:safe_sanitation:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:buffalo.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:cattle_dairy.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:cattle_nondairy.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:chickens.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:goats.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:horses.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:mules.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:pigs.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:sheep.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:bevs_and_spices.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:cereals.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:fibers.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:fruits.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:herbs.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:nuts.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:other_annual.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:other_woody_perennial.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:pulses.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:rice.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:sugar_cane.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:tubers.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:vegetables.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:waste_to_energy:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:fuel_cost:waste_to_energy_value:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ccsq:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:scoe:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ippu:air_pollution:X:cement.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:aviation.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:powered_bikes.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:public.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:rail_passenger.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:road_heavy_regional.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:road_light.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:env_pollution:open_dumping:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ippu:ippu_value:industrial_products:cement.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ippu:ippu_value:industrial_products:steel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ccsq:sector_specific:electricity_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:sector_specific:electricity_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:scoe:sector_specific:electricity_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:sector_specific:electricity_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_to_energy:incineration.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_to_energy:anaerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_to_energy:landfill.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:fuel_cost:waste_to_energy_value:anaerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:fuel_cost:waste_to_energy_value:landfill.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:air_pollution:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:air_pollution:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:air_pollution:X:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:congestion:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:congestion:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:congestion:X:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:congestion:X:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:biogas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:compost.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:incinerated.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:landfilled.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:open_dump.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:recycled.
# La variable se evalúa en System Cost
# ---------Costs for: cb:soil:technical_cost:agriculture_inputs:fertilizer.
# La variable se evalúa en System Cost
# ---------Costs for: cb:soil:land_pollution:N_leaching:fertilizer.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:biomass.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:coal.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:coke.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:X:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:road_safety:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:road_safety:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:road_safety:X:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:road_safety:X:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:water_pollution:wastewater_treatment:P.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:water_pollution:wastewater_treatment:N.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:water_pollution:wastewater_treatment:COD.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:water_pollution:wastewater_treatment:BOD.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lsmm:fuel_cost:waste_to_energy_value:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:ccsq:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:ccsq:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:ccsq:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:biogas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:biomass.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:coal.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:coke.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:hydrocarbon_gas_liquids.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:kerosene.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:nuclear.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:oil.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:other.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:waste.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:biomass.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:coal.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:coke.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:hydrocarbon_gas_liquids.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:kerosene.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:oil.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:biomass.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:coal.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:hydrocarbon_gas_liquids.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:kerosene.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:hydrocarbon_gas_liquids.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:kerosene.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:natural_gas.
# La variable se evalúa en System Cost
#
# ************************************
# *Strategy : PFLO:NDC_25_SCOE_ELEC (2/5)
# ************************************
#
# ---------Costs for: cb:wali:technical_cost:sanitation:unimp_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:imp_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:safeman_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:unimp_urban.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:imp_urban.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:safeman_urban.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:omit_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:technical_cost:electricity:capex.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:technical_cost:electricity:transmission.
# La variable se evalúa en System Cost
# ---------Costs for: change_in_emissions.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:air_pollution:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:air_pollution:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:air_pollution:X:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lndu:ecosystem_services:forests:primary.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lndu:ecosystem_services:forests:secondary.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:freight_transport:aviation.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:freight_transport:rail.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:freight_transport:road_heavy.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:freight_transport:water_borne.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:biogas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:compost.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:incinerated.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:landfilled.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:open_dump.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:recycled.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:tertiary_aerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:tertiary_anaerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:primary.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:secondary_aerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:secondary_anaerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:untreated_with_sewerage.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:human_health:safe_sanitation:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:buffalo.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:cattle_dairy.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:cattle_nondairy.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:chickens.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:goats.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:horses.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:mules.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:pigs.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:sheep.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:bevs_and_spices.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:cereals.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:fibers.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:fruits.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:herbs.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:nuts.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:other_annual.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:other_woody_perennial.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:pulses.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:rice.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:sugar_cane.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:tubers.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:vegetables.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:waste_to_energy:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:fuel_cost:waste_to_energy_value:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ccsq:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:scoe:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ippu:air_pollution:X:cement.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:aviation.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:powered_bikes.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:public.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:rail_passenger.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:road_heavy_regional.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:road_light.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:env_pollution:open_dumping:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ippu:ippu_value:industrial_products:cement.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ippu:ippu_value:industrial_products:steel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ccsq:sector_specific:electricity_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:sector_specific:electricity_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:scoe:sector_specific:electricity_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:sector_specific:electricity_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_to_energy:incineration.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_to_energy:anaerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_to_energy:landfill.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:fuel_cost:waste_to_energy_value:anaerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:fuel_cost:waste_to_energy_value:landfill.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:air_pollution:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:air_pollution:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:air_pollution:X:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:congestion:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:congestion:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:congestion:X:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:congestion:X:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:biogas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:compost.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:incinerated.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:landfilled.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:open_dump.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:recycled.
# La variable se evalúa en System Cost
# ---------Costs for: cb:soil:technical_cost:agriculture_inputs:fertilizer.
# La variable se evalúa en System Cost
# ---------Costs for: cb:soil:land_pollution:N_leaching:fertilizer.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:biomass.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:coal.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:coke.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:X:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:road_safety:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:road_safety:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:road_safety:X:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:road_safety:X:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:water_pollution:wastewater_treatment:P.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:water_pollution:wastewater_treatment:N.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:water_pollution:wastewater_treatment:COD.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:water_pollution:wastewater_treatment:BOD.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lsmm:fuel_cost:waste_to_energy_value:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:ccsq:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:ccsq:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:ccsq:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:biogas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:biomass.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:coal.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:coke.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:hydrocarbon_gas_liquids.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:kerosene.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:nuclear.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:oil.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:other.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:waste.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:biomass.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:coal.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:coke.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:hydrocarbon_gas_liquids.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:kerosene.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:oil.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:biomass.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:coal.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:hydrocarbon_gas_liquids.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:kerosene.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:hydrocarbon_gas_liquids.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:kerosene.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:natural_gas.
# La variable se evalúa en System Cost
#
# ************************************
# *Strategy : PFLO:NDC_25_UNCONDITIONAL (3/5)
# ************************************
#
# ---------Costs for: cb:wali:technical_cost:sanitation:unimp_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:imp_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:safeman_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:unimp_urban.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:imp_urban.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:safeman_urban.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:omit_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:technical_cost:electricity:capex.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:technical_cost:electricity:transmission.
# ...
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:kerosene.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:natural_gas.
# La variable se evalúa en System Cost
#
# ************************************
# *Strategy : PFLO:NDC_25_UNCONDITIONAL_CE (4/5)
# ************************************
#
# ---------Costs for: cb:wali:technical_cost:sanitation:unimp_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:imp_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:safeman_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:unimp_urban.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:imp_urban.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:safeman_urban.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:technical_cost:sanitation:omit_rural.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:technical_cost:electricity:capex.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:technical_cost:electricity:transmission.
# La variable se evalúa en System Cost
# ---------Costs for: change_in_emissions.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:air_pollution:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:air_pollution:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:air_pollution:X:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lndu:ecosystem_services:forests:primary.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lndu:ecosystem_services:forests:secondary.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:freight_transport:aviation.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:freight_transport:rail.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:freight_transport:road_heavy.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:freight_transport:water_borne.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:biogas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:compost.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:incinerated.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:landfilled.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:open_dump.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_management:recycled.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:tertiary_aerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:tertiary_anaerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:primary.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:secondary_aerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:secondary_anaerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:wastewater_treatment:untreated_with_sewerage.
# La variable se evalúa en System Cost
# ---------Costs for: cb:wali:human_health:safe_sanitation:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:buffalo.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:cattle_dairy.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:cattle_nondairy.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:chickens.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:goats.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:horses.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:mules.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:pigs.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lvst:lvst_value:livestock_produced:sheep.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:bevs_and_spices.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:cereals.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:fibers.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:fruits.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:herbs.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:nuts.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:other_annual.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:other_woody_perennial.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:pulses.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:rice.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:sugar_cane.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:tubers.
# La variable se evalúa en System Cost
# ---------Costs for: cb:agrc:crop_value:crops_produced:vegetables.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:technical_cost:waste_to_energy:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:fuel_cost:waste_to_energy_value:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ccsq:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:scoe:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:sector_specific:fuel_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ippu:air_pollution:X:cement.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:aviation.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:powered_bikes.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:public.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:rail_passenger.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:road_heavy_regional.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:system_cost:passenger_transport:road_light.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:env_pollution:open_dumping:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ippu:ippu_value:industrial_products:cement.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ippu:ippu_value:industrial_products:steel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:ccsq:sector_specific:electricity_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:sector_specific:electricity_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:scoe:sector_specific:electricity_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:sector_specific:electricity_cost:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_to_energy:incineration.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_to_energy:anaerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_to_energy:landfill.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:fuel_cost:waste_to_energy_value:anaerobic.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:fuel_cost:waste_to_energy_value:landfill.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:air_pollution:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:air_pollution:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:entc:air_pollution:X:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:congestion:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:congestion:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:congestion:X:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:congestion:X:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:biogas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:compost.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:incinerated.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:landfilled.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:open_dump.
# La variable se evalúa en System Cost
# ---------Costs for: cb:waso:technical_cost:waste_collection:recycled.
# La variable se evalúa en System Cost
# ---------Costs for: cb:soil:technical_cost:agriculture_inputs:fertilizer.
# La variable se evalúa en System Cost
# ---------Costs for: cb:soil:land_pollution:N_leaching:fertilizer.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:biomass.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:coal.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:coke.
# La variable se evalúa en System Cost
# ---------Costs for: cb:inen:air_pollution:X:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:X:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:road_safety:X:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:road_safety:X:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:road_safety:X:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trns:road_safety:X:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:water_pollution:wastewater_treatment:P.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:water_pollution:wastewater_treatment:N.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:water_pollution:wastewater_treatment:COD.
# La variable se evalúa en System Cost
# ---------Costs for: cb:trww:water_pollution:wastewater_treatment:BOD.
# La variable se evalúa en System Cost
# ---------Costs for: cb:lsmm:fuel_cost:waste_to_energy_value:X.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:ccsq:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:ccsq:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:ccsq:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:biogas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:biomass.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:coal.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:coke.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:hydrocarbon_gas_liquids.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:kerosene.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:nuclear.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:oil.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:other.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:entc:waste.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:biomass.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:coal.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:coke.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:hydrocarbon_gas_liquids.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:kerosene.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:inen:oil.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:biomass.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:coal.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:hydrocarbon_gas_liquids.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:kerosene.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:scoe:natural_gas.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:biofuels.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:diesel.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:electricity.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:gasoline.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:hydrocarbon_gas_liquids.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:hydrogen.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:kerosene.
# La variable se evalúa en System Cost
# ---------Costs for: cb:enfu:fuel_cost:trns:natural_gas.
# La variable se evalúa en System Cost

# %%
# Compute Technical Costs
results_tx = cb.compute_technical_cost_for_all_strategies()
# Out:
# ************************************
# *Strategy : PFLO:HBLE (0/5)
# ************************************
#
# ---------Costs for: cb:inen:technical_cost:fuel_switch:lo_heat.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:inen:technical_savings:fuel_switch:lo_heat.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:inen:technical_cost:fuel_switch:hi_heat.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:inen:technical_savings:fuel_switch:hi_heat.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:inen:technical_cost:fuel_switch:all.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:inen:technical_savings:fuel_switch:all.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:inen:technical_cost:efficiency:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_cost:electrification:LDV.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_savings:electrification:LDV.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_cost:electrification:rail.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_savings:electrification:rail.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_cost:fuel_switch:maritime.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_cost:electrification:hdv_vehicles.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_savings:electrification:hdv_vehicles.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_cost:electrification:hdv_charger.
# La variable se evalúa en Transformation Cost
# /opt/anaconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/costs_benefits_ssp/cb_calculate.py:856: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp["difference_variable"] = cb_orm.diff_var
# /opt/anaconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/costs_benefits_ssp/cb_calculate.py:857: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp["difference_value"] = data_merged["difference"]
# /opt/anaconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/costs_benefits_ssp/cb_calculate.py:858: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp["variable"] = cb_orm.output_variable_name
# /opt/anaconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/costs_benefits_ssp/cb_calculate.py:859: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp["value"] = data_merged["values"]
# /opt/anaconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/costs_benefits_ssp/cb_calculate.py:863: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['variable_value_baseline'] = 0
# /opt/anaconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/costs_benefits_ssp/cb_calculate.py:1067: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_output['variable_value_baseline'] = 0
# /opt/anaconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/costs_benefits_ssp/cb_calculate.py:1070: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_output['variable_value_pathway'] = data_merged["difference_value"]
# ---------Costs for: cb:trns:technical_cost:efficiency:electric.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_cost:efficiency:non_electric.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_cost:efficiency:all.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:scoe:technical_cost:efficiency:appliance.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:scoe:technical_cost:fuel_switch:heat_pumps.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:scoe:technical_savings:fuel_switch:heat_pumps.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:scoe:technical_cost:efficiency:building_shell.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:entc:technical_cost:loss_reduction:electricity.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:ippu:technical_cost:clinker:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:ippu:technical_cost:abating_gases:n2o.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:ippu:technical_cost:abating_gases:pfcs.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:ippu:technical_cost:abating_gases:other_fgases.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:fgtv:technical_cost:flaring:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:fgtv:technical_cost:leaks:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:waso:technical_cost:consumer_food_waste:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:waso:consumer_savings:consumer_food_waste:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:lvst:technical_cost:ent_ferm_mgmt:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:agrc:technical_cost:rice_mgmt:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:agrc:technical_cost:producer_food_waste:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:agrc:technical_savings:producer_food_waste:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:agrc:technical_cost:increase_productivity:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:lvst:technical_cost:increase_productivity:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:pflo:human_health:better_diets:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:pflo:consumer_savings:better_diets:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:lndu:technical_cost:silvopasture:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:lndu:technical_cost:all_secondary_forests:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:ippu:technical_cost:industrial_ccs:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:agrc:consumer_savings:cons_ag_land_value:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:agrc:technical_savings:cons_ag:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:lsmm:technical_cost:manure_management_cattle_pigs.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:lsmm:technical_cost:manure_management_poultry.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:lsmm:technical_cost:manure_management_other.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:lsmm:technical_cost:biogas_capture.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:waso:technical_cost:biogas_capture.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:entc:technical_savings:electricity:opex.
# La variable se evalúa en Transformation Cost
#
# ************************************
# *Strategy : PFLO:NDC_25 (1/5)
# ************************************
#
# ---------Costs for: cb:inen:technical_cost:fuel_switch:lo_heat.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:inen:technical_savings:fuel_switch:lo_heat.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:inen:technical_cost:fuel_switch:hi_heat.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:inen:technical_savings:fuel_switch:hi_heat.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:inen:technical_cost:fuel_switch:all.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:inen:technical_savings:fuel_switch:all.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:inen:technical_cost:efficiency:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_cost:electrification:LDV.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_savings:electrification:LDV.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_cost:electrification:hdv_vehicles.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_savings:electrification:hdv_vehicles.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_cost:electrification:hdv_charger.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_cost:efficiency:non_electric.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_cost:efficiency:all.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:scoe:technical_cost:fuel_switch:heat_pumps.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:scoe:technical_savings:fuel_switch:heat_pumps.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:scoe:technical_cost:efficiency:building_shell.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:entc:technical_cost:loss_reduction:electricity.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:ippu:technical_cost:clinker:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:waso:technical_cost:consumer_food_waste:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:waso:consumer_savings:consumer_food_waste:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:lvst:technical_cost:ent_ferm_mgmt:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:agrc:technical_cost:increase_productivity:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:lvst:technical_cost:increase_productivity:X.
# La variable se evalúa en Transformation Cost
# /opt/anaconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/costs_benefits_ssp/cb_calculate.py:1067: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_output['variable_value_baseline'] = 0
# /opt/anaconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/costs_benefits_ssp/cb_calculate.py:1070: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_output['variable_value_pathway'] = data_merged["difference_value"]
# ---------Costs for: cb:lndu:technical_cost:silvopasture:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:lndu:technical_cost:all_secondary_forests:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:agrc:consumer_savings:cons_ag_land_value:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:agrc:technical_savings:cons_ag:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:waso:technical_cost:biogas_capture.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:entc:technical_savings:electricity:opex.
# La variable se evalúa en Transformation Cost
#
# ************************************
# *Strategy : PFLO:NDC_25_SCOE_ELEC (2/5)
# ************************************
#
# ---------Costs for: cb:inen:technical_cost:fuel_switch:lo_heat.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:inen:technical_savings:fuel_switch:lo_heat.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:inen:technical_cost:fuel_switch:hi_heat.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:inen:technical_savings:fuel_switch:hi_heat.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:inen:technical_cost:fuel_switch:all.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:inen:technical_savings:fuel_switch:all.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:inen:technical_cost:efficiency:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_cost:electrification:LDV.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_savings:electrification:LDV.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_cost:electrification:hdv_vehicles.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_savings:electrification:hdv_vehicles.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_cost:electrification:hdv_charger.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_cost:efficiency:non_electric.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:trns:technical_cost:efficiency:all.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:scoe:technical_cost:fuel_switch:heat_pumps.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:scoe:technical_savings:fuel_switch:heat_pumps.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:scoe:technical_cost:efficiency:building_shell.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:entc:technical_cost:loss_reduction:electricity.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:ippu:technical_cost:clinker:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:waso:technical_cost:consumer_food_waste:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:waso:consumer_savings:consumer_food_waste:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:lvst:technical_cost:ent_ferm_mgmt:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:agrc:technical_cost:increase_productivity:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:lvst:technical_cost:increase_productivity:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:lndu:technical_cost:silvopasture:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:lndu:technical_cost:all_secondary_forests:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:agrc:consumer_savings:cons_ag_land_value:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:agrc:technical_savings:cons_ag:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:waso:technical_cost:biogas_capture.
# La variable se evalúa en Transformation Cost
# /opt/anaconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/costs_benefits_ssp/cb_calculate.py:1067: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_output['variable_value_baseline'] = 0
# /opt/anaconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/costs_benefits_ssp/cb_calculate.py:1070: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_output['variable_value_pathway'] = data_merged["difference_value"]
# ---------Costs for: cb:entc:technical_savings:electricity:opex.
# La variable se evalúa en Transformation Cost
#
# ************************************
# *Strategy : PFLO:NDC_25_UNCONDITIONAL (3/5)
# ************************************
#
# ---------Costs for: cb:scoe:technical_cost:fuel_switch:heat_pumps.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:scoe:technical_savings:fuel_switch:heat_pumps.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:scoe:technical_cost:efficiency:building_shell.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:waso:technical_cost:biogas_capture.
# La variable se evalúa en Transformation Cost
#
# ************************************
# *Strategy : PFLO:NDC_25_UNCONDITIONAL_CE (4/5)
# ************************************
#
# ---------Costs for: cb:scoe:technical_cost:fuel_switch:heat_pumps.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:scoe:technical_savings:fuel_switch:heat_pumps.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:scoe:technical_cost:efficiency:building_shell.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:ippu:technical_cost:clinker:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:agrc:technical_cost:increase_productivity:X.
# La variable se evalúa en Transformation Cost
# ---------Costs for: cb:waso:technical_cost:biogas_capture.
# La variable se evalúa en Transformation Cost
# /opt/anaconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/costs_benefits_ssp/cb_calculate.py:1067: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_output['variable_value_baseline'] = 0
# /opt/anaconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/costs_benefits_ssp/cb_calculate.py:1070: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_output['variable_value_pathway'] = data_merged["difference_value"]

# %%
# Combine results
results_all = pd.concat([results_system, results_tx], ignore_index = True)

#-------------POST PROCESS SIMULATION RESULTS---------------
# Post process interactions among strategies that affect the same variables
results_all_pp = cb.cb_process_interactions(results_all)

# SHIFT any stray costs incurred from 2015 to 2025 to 2025 and 2035
results_all_pp_shifted = cb.cb_shift_costs(results_all_pp)
# Out:
# Resolving Interactions in SCOE : TX:SCOE:INC_EFFICIENCY_APPLIANCE, TX:SCOE:SHIFT_FUEL_HEAT, TX:SCOE:SHIFT_FUEL_HEAT, TX:SCOE:DEC_DEMAND_HEAT
# Resolving Interactions in INEN : TX:INEN:SHIFT_FUEL_HEAT, TX:INEN:SHIFT_FUEL_HEAT, TX:INEN:SHIFT_FUEL_HEAT, TX:INEN:SHIFT_FUEL_HEAT, TX:INEN:SHIFT_FUEL_HEAT, TX:INEN:SHIFT_FUEL_HEAT, TX:INEN:INC_EFFICIENCY_ENERGY
# Resolving Interactions in SCOE : TX:SCOE:SHIFT_FUEL_HEAT, TX:SCOE:SHIFT_FUEL_HEAT, TX:SCOE:DEC_DEMAND_HEAT
# Resolving Interactions in INEN : TX:INEN:SHIFT_FUEL_HEAT, TX:INEN:SHIFT_FUEL_HEAT, TX:INEN:SHIFT_FUEL_HEAT, TX:INEN:SHIFT_FUEL_HEAT, TX:INEN:SHIFT_FUEL_HEAT, TX:INEN:SHIFT_FUEL_HEAT, TX:INEN:INC_EFFICIENCY_ENERGY
# Resolving Interactions in SCOE : TX:SCOE:SHIFT_FUEL_HEAT, TX:SCOE:SHIFT_FUEL_HEAT, TX:SCOE:DEC_DEMAND_HEAT
# Resolving Interactions in INEN : TX:INEN:SHIFT_FUEL_HEAT, TX:INEN:SHIFT_FUEL_HEAT, TX:INEN:SHIFT_FUEL_HEAT, TX:INEN:SHIFT_FUEL_HEAT, TX:INEN:SHIFT_FUEL_HEAT, TX:INEN:SHIFT_FUEL_HEAT, TX:INEN:INC_EFFICIENCY_ENERGY
# Resolving Interactions in SCOE : TX:SCOE:SHIFT_FUEL_HEAT, TX:SCOE:SHIFT_FUEL_HEAT, TX:SCOE:DEC_DEMAND_HEAT
# Resolving Interactions in INEN :
# No interactions, skipping... PFLO:NDC_25_UNCONDITIONAL
# Resolving Interactions in SCOE : TX:SCOE:SHIFT_FUEL_HEAT, TX:SCOE:SHIFT_FUEL_HEAT, TX:SCOE:DEC_DEMAND_HEAT
# Resolving Interactions in INEN :
# No interactions, skipping... PFLO:NDC_25_UNCONDITIONAL_CE
# /opt/anaconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/costs_benefits_ssp/cb_calculate.py:660: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_pre2025["variable"] = res_pre2025["variable"] + "_shifted" + (res_pre2025["time_period"]+SSP_GLOBAL_TIME_PERIOD_0).astype(str)#create a new variable so they can be recognized as shifted costs
# /opt/anaconda3/envs/ssp_uganda_env/lib/python3.11/site-packages/costs_benefits_ssp/cb_calculate.py:661: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_pre2025["time_period"] = res_pre2025["time_period"]+SSP_GLOBAL_TIME_PERIOD_TX_START #shift the time period

# %%
results_all_pp_shifted.head()
# Out:
#   strategy_code  future_id  region  time_period   difference_variable  \
# 0     PFLO:HBLE          0  uganda            4  pop_unimproved_rural
# 1     PFLO:HBLE          0  uganda            5  pop_unimproved_rural
# 2     PFLO:HBLE          0  uganda            6  pop_unimproved_rural
# 3     PFLO:HBLE          0  uganda            7  pop_unimproved_rural
# 4     PFLO:HBLE          0  uganda            8  pop_unimproved_rural
#
#    variable_value_baseline  variable_value_pathway  difference_value  \
# 0             1.932346e+07            1.932346e+07               0.0
# 1             1.951974e+07            1.951974e+07               0.0
# 2             1.896047e+07            1.896047e+07               0.0
# 3             1.837001e+07            1.837001e+07               0.0
# 4             1.774752e+07            1.774752e+07               0.0
#
#                                         variable  value
# 0  cb:wali:technical_cost:sanitation:unimp_rural    0.0
# 1  cb:wali:technical_cost:sanitation:unimp_rural    0.0
# 2  cb:wali:technical_cost:sanitation:unimp_rural    0.0
# 3  cb:wali:technical_cost:sanitation:unimp_rural    0.0
# 4  cb:wali:technical_cost:sanitation:unimp_rural    0.0

# %%
ssp_data.head()
# Out:
#    primary_id  region  time_period  area_agrc_crops_bevs_and_spices  \
# 0           0  uganda            4                    634960.593061
# 1           0  uganda            5                    640126.452982
# 2           0  uganda            6                    642767.262368
# 3           0  uganda            7                    645322.479649
# 4           0  uganda            8                    647798.760608
#
#    area_agrc_crops_cereals  area_agrc_crops_fibers  area_agrc_crops_fruits  \
# 0             2.025945e+06           156073.139455            1.131815e+06
# 1             2.042427e+06           157342.906406            1.141024e+06
# 2             2.050853e+06           157992.016628            1.145731e+06
# 3             2.059006e+06           158620.088334            1.150285e+06
# 4             2.066907e+06           159228.757514            1.154699e+06
#
#    area_agrc_crops_herbs_and_other_perennial_crops  area_agrc_crops_nuts  \
# 0                                       505.429083         513832.892470
# 1                                       509.541112         518013.291655
# 2                                       511.643198         520150.329354
# 3                                       513.677153         522218.102852
# 4                                       515.648274         524221.998246
#
#    area_agrc_crops_other_annual  ...  \
# 0                  2.915383e+06  ...
# 1                  2.939102e+06  ...
# 2                  2.951227e+06  ...
# 3                  2.962959e+06  ...
# 4                  2.974329e+06  ...
#
#    yf_agrc_herbs_and_other_perennial_crops_tonne_ha  yf_agrc_nuts_tonne_ha  \
# 0                                          2.172065               0.458120
# 1                                          2.196794               0.611231
# 2                                          2.210866               0.841393
# 3                                          2.225270               0.400800
# 4                                          2.225270               0.400800
#
#    yf_agrc_other_annual_tonne_ha  yf_agrc_other_woody_perennial_tonne_ha  \
# 0                       1.528325                                  0.3674
# 1                       1.681739                                  0.3674
# 2                       2.293907                                  0.3674
# 3                       2.699337                                  0.3674
# 4                       2.699337                                  0.3674
#
#    yf_agrc_pulses_tonne_ha  yf_agrc_rice_tonne_ha  \
# 0                 0.799814               2.970174
# 1                 0.805568               3.032345
# 2                 0.807398               3.080626
# 3                 0.810044               3.094956
# 4                 0.810044               3.094956
#
#    yf_agrc_sugar_cane_tonne_ha  yf_agrc_tubers_tonne_ha  \
# 0                    77.726965                 4.805888
# 1                    78.023706                 4.440105
# 2                    61.430414                 4.911305
# 3                    77.255948                 4.924276
# 4                    77.255948                 4.924276
#
#    yf_agrc_vegetables_and_vines_tonne_ha  \
# 0                               4.035314
# 1                               4.013004
# 2                               4.023409
# 3                               4.030111
# 4                               4.030111
#
#    yf_lndu_supremum_pastures_tonne_per_ha
# 0                                   92.81
# 1                                   92.81
# 2                                   92.81
# 3                                   92.81
# 4                                   92.81
#
# [5 rows x 4107 columns]

# %% [markdown]
# # Indoor air pollution benef

# %% [markdown]
# Health co-benefit from reduced household air pollution
#
# To monetize the health benefits of reducing indoor air pollution from the use of traditional biomass stoves, we drew on estimates from the BAR-HAP model (The Benefits of Action to Reduce Household Air Pollution; WHO, 2021).
# The study reports cost-effectiveness ratios ranging from 674 – 869 USD per DALY avoided for clean cooking interventions in Nepal, meaning that each avoided disability-adjusted life year (DALY) costs approximately 700 USD.
#
# To adapt this metric to Uganda, we scaled the cost-effectiveness ratio by the relative difference in GDP per capita between Nepal (~1,450 USD) and Uganda (~1,070 USD), yielding an adjusted range of ≈ 500–640 USD per DALY avoided.
# Assuming that the transition from solid fuels to clean cooking solutions avoids about 0.1 DALY per person per year, the implied annual health benefit equals 50–64 USD per person.
#
# Given an average household size of five, this corresponds to an estimated 250–320 USD per household per year in health-related economic benefits.
#
# This adjusted value was used in the cost–benefit analysis as the annual household health co-benefit of eliminating exposure to indoor air pollution from firewood and other solid fuels in Uganda.

# %%
# --- Merge strategy attributes into ssp_data ---
# Needed to group transitions by strategy and retrieve strategy_code / future_id.
df_ssp = ssp_data.merge(
    att_primary[['primary_id', 'strategy_id', 'future_id']],
    on='primary_id', how='left'
)
df_ssp = df_ssp.merge(
    att_strategy[['strategy_id', 'strategy_code']],
    on='strategy_id', how='left'
)

# Variable maps: SISEPUEDE fuel-fraction columns -> readable transition labels.
# Used to detect which population share leaves (out_of) or enters (into) each fuel.
var_map_out = {
    'frac_scoe_heat_energy_residential_solid_biomass':             'est_out_of_biomass',
    'frac_scoe_heat_energy_residential_electricity':               'est_out_of_elec',
    'frac_scoe_heat_energy_residential_hydrocarbon_gas_liquids':   'est_out_of_gas',
}

var_map_into = {
    'frac_scoe_heat_energy_residential_solid_biomass':             'est_into_biomass',
    'frac_scoe_heat_energy_residential_electricity':               'est_into_elec',
    'frac_scoe_heat_energy_residential_hydrocarbon_gas_liquids':   'est_into_gas',
}

# %%
# --- Helper functions to compute period-over-period fuel-fraction transitions ---

def add_out_of(df, time_col, group_cols, var_map):
    """
    out_of(t) = max(frac(t) - frac(t+1), 0)
    Captures the share of population that leaves a given fuel between t and t+1.
    Clipped at 0 so that increases in a fuel do not produce negative 'out_of' values.
    """
    df = df.sort_values(group_cols + [time_col]).copy()
    for frac_var, out_var in var_map.items():
        next_frac = df.groupby(group_cols, sort=False)[frac_var].shift(-1)
        df[out_var] = (df[frac_var] - next_frac).clip(lower=0).fillna(0)
    return df


def add_into(df, time_col, group_cols, var_map):
    """
    into(t) = max(frac(t+1) - frac(t), 0)
    Captures the share of population that enters a given fuel between t and t+1.
    Clipped at 0 so that decreases in a fuel do not produce negative 'into' values.
    """
    df = df.sort_values(group_cols + [time_col]).copy()
    for frac_var, into_var in var_map.items():
        next_frac = df.groupby(group_cols, sort=False)[frac_var].shift(-1)
        df[into_var] = (next_frac - df[frac_var]).clip(lower=0).fillna(0)
    return df

# %%
def add_transitions(df):
    """
    Derives mutually exclusive household fuel-switching transitions per period.
    Priority order prevents double-counting:
      1. biomass -> gas  (matched first)
      2. biomass -> elec (remaining biomass leavers)
      3. gas    -> elec  (remaining electricity entrants)
    Each transition value is a fraction of total population.
    """
    df = df.copy()

    # 1. Biomass -> Gas
    df['biomass_to_gas'] = df[['est_out_of_biomass', 'est_into_gas']].min(axis=1)
    rem_out_biomass      = df['est_out_of_biomass'] - df['biomass_to_gas']
    rem_into_gas         = df['est_into_gas']       - df['biomass_to_gas']

    # 2. Biomass -> Elec (with remaining biomass leavers)
    df['biomass_to_elec'] = pd.concat([rem_out_biomass, df['est_into_elec']], axis=1).min(axis=1)
    rem_into_elec         = df['est_into_elec'] - df['biomass_to_elec']

    # 3. Gas -> Elec (with remaining electricity entrants)
    df['gas_to_elec'] = pd.concat([df['est_out_of_gas'], rem_into_elec], axis=1).min(axis=1)

    return df


# Apply: compute out_of, into, and final transitions
df_ssp = add_out_of(df_ssp,  time_col='time_period', group_cols=['strategy_id'], var_map=var_map_out)
df_ssp = add_into(df_ssp,    time_col='time_period', group_cols=['strategy_id', 'region'], var_map=var_map_into)
df_ssp = add_transitions(df_ssp)

df_ssp[['time_period', 'strategy_id', 'biomass_to_gas', 'biomass_to_elec', 'gas_to_elec']].head(10)
# Out:
#    time_period  strategy_id  biomass_to_gas  biomass_to_elec  gas_to_elec
# 0            4            0        0.009584         0.014894          0.0
# 1            5            0        0.010887         0.017394          0.0
# 2            6            0        0.000000         0.000000          0.0
# 3            7            0        0.000000         0.000000          0.0
# 4            8            0        0.000000         0.000000          0.0
# 5            9            0        0.000000         0.000000          0.0
# 6           10            0        0.000000         0.000000          0.0
# 7           11            0        0.008477         0.000000          0.0
# 8           12            0        0.012615         0.000000          0.0
# 9           13            0        0.018555         0.000000          0.0

# %%
# --- Per-capita cost and benefit factors by transition type ---
# Source: WHO BAR-HAP model (2021), scaled to Uganda GDP per capita.
# Four policy instruments are considered (stove subsidy, fuel subsidy, financing,
# behavioral change campaign). Because no data is available on the share of
# households reached by each instrument, factors are averaged across policies
# (unweighted). Values are in PPP 2019 USD per person.
# Costs are negative (government expenditure); benefits are positive (health gains).

df_factors_raw = pd.DataFrame([
    # --- biomass -> gas ---
    {'transition': 'biomass_to_gas',  'policy': 'subsidy_for_stove',                    'cost_per_capita_ppp_2019': -1.349440118, 'benefit_per_capita_ppp_2019':  4.767680737},
    {'transition': 'biomass_to_gas',  'policy': 'fuel_subsidy',                         'cost_per_capita_ppp_2019': -3.431367796, 'benefit_per_capita_ppp_2019':  5.341173225},
    {'transition': 'biomass_to_gas',  'policy': 'financing',                             'cost_per_capita_ppp_2019': -3.368400432, 'benefit_per_capita_ppp_2019': 12.444250280},
    {'transition': 'biomass_to_gas',  'policy': 'intensive_behavioral_change_campaign',  'cost_per_capita_ppp_2019': -2.012617193, 'benefit_per_capita_ppp_2019':  6.868823172},
    # --- biomass -> elec ---
    {'transition': 'biomass_to_elec', 'policy': 'subsidy_for_stove',                    'cost_per_capita_ppp_2019': -2.659697106, 'benefit_per_capita_ppp_2019':  9.566241834},
    {'transition': 'biomass_to_elec', 'policy': 'fuel_subsidy',                         'cost_per_capita_ppp_2019': -6.229455845, 'benefit_per_capita_ppp_2019': 11.330111010},
    {'transition': 'biomass_to_elec', 'policy': 'financing',                             'cost_per_capita_ppp_2019': -4.838372823, 'benefit_per_capita_ppp_2019': 17.561156150},
    {'transition': 'biomass_to_elec', 'policy': 'intensive_behavioral_change_campaign',  'cost_per_capita_ppp_2019': -3.535655711, 'benefit_per_capita_ppp_2019': 11.564970400},
])

# Average across policies — one factor row per transition type
df_factors = (
    df_factors_raw
    .groupby('transition', as_index=False)
    .agg(
        cost_per_capita_ppp_2019=('cost_per_capita_ppp_2019',    'mean'),
        benefit_per_capita_ppp_2019=('benefit_per_capita_ppp_2019', 'mean'),
    )
)
df_factors
# Out:
#         transition  cost_per_capita_ppp_2019  benefit_per_capita_ppp_2019
# 0  biomass_to_elec                 -4.315795                    12.505620
# 1   biomass_to_gas                 -2.540456                     7.355482

# %%
# --- Monetization ---
# Only biomass_to_gas and biomass_to_elec generate indoor air pollution benefits
# (gas_to_elec does not alter indoor air quality in the same way).

transitions = ['biomass_to_gas', 'biomass_to_elec']

# Melt to long format: one row per (time_period, strategy_id, transition)
ssp_long = (
    df_ssp
    .melt(
        id_vars=['time_period', 'strategy_id', 'population_gnrl_total'],
        value_vars=transitions,
        var_name='transition',
        value_name='transition_frac',
    )
)

# Population affected = fraction transitioning × total population
ssp_long['population_affected'] = ssp_long['transition_frac'] * ssp_long['population_gnrl_total']

# Merge averaged per-capita factors and compute monetary values (USD PPP 2019)
cb_ap = ssp_long.merge(df_factors, on='transition', how='left')
cb_ap['total_cost']    = cb_ap['population_affected'] * cb_ap['cost_per_capita_ppp_2019']
cb_ap['total_benefit'] = cb_ap['population_affected'] * cb_ap['benefit_per_capita_ppp_2019']
cb_ap['net_benefit']   = cb_ap['total_benefit'] + cb_ap['total_cost']   # cost is negative

cb_ap.head()
# Out:
#    time_period  strategy_id  population_gnrl_total      transition  \
# 0            4            0               39853824  biomass_to_gas
# 1            5            0               40996690  biomass_to_gas
# 2            6            0               42172327  biomass_to_gas
# 3            7            0               43381679  biomass_to_gas
# 4            8            0               44625710  biomass_to_gas
#
#    transition_frac  population_affected  cost_per_capita_ppp_2019  \
# 0         0.009584        381955.329412                 -2.540456
# 1         0.010887        446317.967983                 -2.540456
# 2         0.000000             0.000000                 -2.540456
# 3         0.000000             0.000000                 -2.540456
# 4         0.000000             0.000000                 -2.540456
#
#    benefit_per_capita_ppp_2019    total_cost  total_benefit   net_benefit
# 0                     7.355482 -9.703409e+05   2.809465e+06  1.839125e+06
# 1                     7.355482 -1.133851e+06   3.282884e+06  2.149032e+06
# 2                     7.355482 -0.000000e+00   0.000000e+00  0.000000e+00
# 3                     7.355482 -0.000000e+00   0.000000e+00  0.000000e+00
# 4                     7.355482 -0.000000e+00   0.000000e+00  0.000000e+00

# %%
cb_ap[(cb_ap['strategy_id'] == 6004) & (cb_ap['time_period'] == 4)]
# Out:
#      time_period  strategy_id  population_gnrl_total       transition  \
# 52             4         6004               39853824   biomass_to_gas
# 364            4         6004               39853824  biomass_to_elec
#
#      transition_frac  population_affected  cost_per_capita_ppp_2019  \
# 52          0.009584        381955.329412                 -2.540456
# 364         0.014894        593584.192686                 -4.315795
#
#      benefit_per_capita_ppp_2019    total_cost  total_benefit   net_benefit
# 52                      7.355482 -9.703409e+05   2.809465e+06  1.839125e+06
# 364                    12.505620 -2.561788e+06   7.423138e+06  4.861350e+06

# %%
# --- Aggregate net benefit by (strategy_id, time_period) ---
# Sum net_benefit across both transitions to get a single CBA value per
# strategy/period, then attach strategy metadata for downstream use.

merged = (
    cb_ap
    .groupby(['strategy_id', 'time_period'], as_index=False)['net_benefit']
    .sum()
    .rename(columns={'net_benefit': 'value'})
)

# Exclude baseline (strategy_id == 0); benefits are relative to BAU by construction
merged = merged[merged['strategy_id'] != 0].copy()

# Re-attach strategy_code and future_id from attribute tables
merged = merged.merge(att_primary[['primary_id', 'strategy_id', 'future_id']].drop_duplicates('strategy_id'),
                      on='strategy_id', how='left')
merged = merged.merge(att_strategy[['strategy_id', 'strategy_code']], on='strategy_id', how='left')

# %%
merged
# Out:
#      strategy_id  time_period         value  primary_id  future_id  \
# 0           6004            4  6.700475e+06      700070          0
# 1           6004            5  7.989096e+06      700070          0
# 2           6004            6  0.000000e+00      700070          0
# 3           6004            7  0.000000e+00      700070          0
# 4           6004            8  0.000000e+00      700070          0
# ..           ...          ...           ...         ...        ...
# 255         6012           51  0.000000e+00      780078          0
# 256         6012           52  0.000000e+00      780078          0
# 257         6012           53  0.000000e+00      780078          0
# 258         6012           54  0.000000e+00      780078          0
# 259         6012           55  0.000000e+00      780078          0
#
#                     strategy_code
# 0                       PFLO:HBLE
# 1                       PFLO:HBLE
# 2                       PFLO:HBLE
# 3                       PFLO:HBLE
# 4                       PFLO:HBLE
# ..                            ...
# 255  PFLO:NDC_25_UNCONDITIONAL_CE
# 256  PFLO:NDC_25_UNCONDITIONAL_CE
# 257  PFLO:NDC_25_UNCONDITIONAL_CE
# 258  PFLO:NDC_25_UNCONDITIONAL_CE
# 259  PFLO:NDC_25_UNCONDITIONAL_CE
#
# [260 rows x 6 columns]

# %%
# Add metadata columns required by results_all_pp_shifted schema
merged['region']              = 'uganda'
merged['difference_variable'] = 'frac_scoe_heat_energy_residential_solid_biomass'
merged['variable']            = 'cb:scoe:indoor_air_pollution'

# Select only the columns that results_all_pp_shifted expects
merged = merged[['strategy_code', 'future_id', 'region', 'time_period',
                  'difference_variable', 'value', 'variable']]

merged.head()
# Out:
#   strategy_code  future_id  region  time_period  \
# 0     PFLO:HBLE          0  uganda            4
# 1     PFLO:HBLE          0  uganda            5
# 2     PFLO:HBLE          0  uganda            6
# 3     PFLO:HBLE          0  uganda            7
# 4     PFLO:HBLE          0  uganda            8
#
#                                difference_variable         value  \
# 0  frac_scoe_heat_energy_residential_solid_biomass  6.700475e+06
# 1  frac_scoe_heat_energy_residential_solid_biomass  7.989096e+06
# 2  frac_scoe_heat_energy_residential_solid_biomass  0.000000e+00
# 3  frac_scoe_heat_energy_residential_solid_biomass  0.000000e+00
# 4  frac_scoe_heat_energy_residential_solid_biomass  0.000000e+00
#
#                        variable
# 0  cb:scoe:indoor_air_pollution
# 1  cb:scoe:indoor_air_pollution
# 2  cb:scoe:indoor_air_pollution
# 3  cb:scoe:indoor_air_pollution
# 4  cb:scoe:indoor_air_pollution

# %%
# Optional: save air pollution CBA to CSV for inspection
#merged.to_csv(os.path.join(CB_OUTPUT, 'cba_indoor_air_pollution.csv'), index=False)

# %%
# (placeholder — cell reserved for future use)

# %%
# (placeholder — cell reserved for future use)

# %%
results_all_pp_shifted= pd.concat([results_all_pp_shifted, merged], ignore_index = True)

# %%
results_all_pp_shifted.head()
# Out:
#   strategy_code  future_id  region  time_period   difference_variable  \
# 0     PFLO:HBLE          0  uganda            4  pop_unimproved_rural
# 1     PFLO:HBLE          0  uganda            5  pop_unimproved_rural
# 2     PFLO:HBLE          0  uganda            6  pop_unimproved_rural
# 3     PFLO:HBLE          0  uganda            7  pop_unimproved_rural
# 4     PFLO:HBLE          0  uganda            8  pop_unimproved_rural
#
#    variable_value_baseline  variable_value_pathway  difference_value  \
# 0             1.932346e+07            1.932346e+07               0.0
# 1             1.951974e+07            1.951974e+07               0.0
# 2             1.896047e+07            1.896047e+07               0.0
# 3             1.837001e+07            1.837001e+07               0.0
# 4             1.774752e+07            1.774752e+07               0.0
#
#                                         variable  value
# 0  cb:wali:technical_cost:sanitation:unimp_rural    0.0
# 1  cb:wali:technical_cost:sanitation:unimp_rural    0.0
# 2  cb:wali:technical_cost:sanitation:unimp_rural    0.0
# 3  cb:wali:technical_cost:sanitation:unimp_rural    0.0
# 4  cb:wali:technical_cost:sanitation:unimp_rural    0.0

# %%
results_all_pp_shifted.tail()
# Out:
#                       strategy_code  future_id  region  time_period  \
# 63553  PFLO:NDC_25_UNCONDITIONAL_CE          0  uganda           51
# 63554  PFLO:NDC_25_UNCONDITIONAL_CE          0  uganda           52
# 63555  PFLO:NDC_25_UNCONDITIONAL_CE          0  uganda           53
# 63556  PFLO:NDC_25_UNCONDITIONAL_CE          0  uganda           54
# 63557  PFLO:NDC_25_UNCONDITIONAL_CE          0  uganda           55
#
#                                    difference_variable  \
# 63553  frac_scoe_heat_energy_residential_solid_biomass
# 63554  frac_scoe_heat_energy_residential_solid_biomass
# 63555  frac_scoe_heat_energy_residential_solid_biomass
# 63556  frac_scoe_heat_energy_residential_solid_biomass
# 63557  frac_scoe_heat_energy_residential_solid_biomass
#
#        variable_value_baseline  variable_value_pathway  difference_value  \
# 63553                      NaN                     NaN               NaN
# 63554                      NaN                     NaN               NaN
# 63555                      NaN                     NaN               NaN
# 63556                      NaN                     NaN               NaN
# 63557                      NaN                     NaN               NaN
#
#                            variable  value
# 63553  cb:scoe:indoor_air_pollution    0.0
# 63554  cb:scoe:indoor_air_pollution    0.0
# 63555  cb:scoe:indoor_air_pollution    0.0
# 63556  cb:scoe:indoor_air_pollution    0.0
# 63557  cb:scoe:indoor_air_pollution    0.0

# %% [markdown]
# ## Reshape to load into tableau

# %%
# --- Read cost-benefit data ---
cb_data = results_all_pp_shifted.copy()

# Split 'variable' into components: name, sector, cb_type, item_1, item_2
# (Assumes exactly 5 colon-separated parts; if there are more colons inside the last field,
# they will be kept in item_2 thanks to n=4)
cb_chars = cb_data["variable"].astype(str).str.split(":", n=4, expand=True)
cb_chars.columns = ["name", "sector", "cb_type", "item_1", "item_2"]
cb_data = pd.concat([cb_data, cb_chars], axis=1)

# %%
cb_data.head()
# Out:
#   strategy_code  future_id  region  time_period   difference_variable  \
# 0     PFLO:HBLE          0  uganda            4  pop_unimproved_rural
# 1     PFLO:HBLE          0  uganda            5  pop_unimproved_rural
# 2     PFLO:HBLE          0  uganda            6  pop_unimproved_rural
# 3     PFLO:HBLE          0  uganda            7  pop_unimproved_rural
# 4     PFLO:HBLE          0  uganda            8  pop_unimproved_rural
#
#    variable_value_baseline  variable_value_pathway  difference_value  \
# 0             1.932346e+07            1.932346e+07               0.0
# 1             1.951974e+07            1.951974e+07               0.0
# 2             1.896047e+07            1.896047e+07               0.0
# 3             1.837001e+07            1.837001e+07               0.0
# 4             1.774752e+07            1.774752e+07               0.0
#
#                                         variable  value name sector  \
# 0  cb:wali:technical_cost:sanitation:unimp_rural    0.0   cb   wali
# 1  cb:wali:technical_cost:sanitation:unimp_rural    0.0   cb   wali
# 2  cb:wali:technical_cost:sanitation:unimp_rural    0.0   cb   wali
# 3  cb:wali:technical_cost:sanitation:unimp_rural    0.0   cb   wali
# 4  cb:wali:technical_cost:sanitation:unimp_rural    0.0   cb   wali
#
#           cb_type      item_1       item_2
# 0  technical_cost  sanitation  unimp_rural
# 1  technical_cost  sanitation  unimp_rural
# 2  technical_cost  sanitation  unimp_rural
# 3  technical_cost  sanitation  unimp_rural
# 4  technical_cost  sanitation  unimp_rural

# %%
cb_data['strategy_code'].unique()
# Out:
# array(['PFLO:HBLE', 'PFLO:NDC_25', 'PFLO:NDC_25_SCOE_ELEC',
#        'PFLO:NDC_25_UNCONDITIONAL', 'PFLO:NDC_25_UNCONDITIONAL_CE'],
#       dtype=object)

# %%
# Scale value from USD to billions (divide by 1e9)
if "value" in cb_data.columns:
    cb_data["value"] = cb_data["value"] / 1e9

# --- Remove "shifted" entries ---
# Remove rows where item_2 contains "shifted"
cb_data = cb_data[~cb_data["item_2"].astype(str).str.contains("shifted", na=False)]

# Remove any remaining rows where variable contains "shifted2"
cb_data = cb_data[~cb_data["variable"].astype(str).str.contains("shifted2", na=False)]

# --- Add Year column (Year = time_period + 2015) ---
cb_data["Year"] = cb_data["time_period"] + 2015

# %% [markdown]
# **This Section Needs Manual Tunnning**

# %%
cb_data.strategy_code.unique()
# Out:
# array(['PFLO:HBLE', 'PFLO:NDC_25', 'PFLO:NDC_25_SCOE_ELEC',
#        'PFLO:NDC_25_UNCONDITIONAL', 'PFLO:NDC_25_UNCONDITIONAL_CE'],
#       dtype=object)

# %%
# Harmonize strategy name changes with a single mapping (no duplicate replacements)
strategy_name_map = {
    "PFLO:HBLE": "PFLO:HBLE",
    "PFLO:NDC_25_SCOE_ELEC": "PFLO:NDC_25_SCOE_ELEC",
    "PFLO:NDC_25_UNCONDITIONAL": "NDC_25_UNCONDITIONAL",
    "PFLO:NDC_25_UNCONDITIONAL_CE": "PFLO:NDC_25_UNCONDITIONAL_CE"
}

cb_data["strategy"] = (
    cb_data["strategy_code"].astype(str).map(strategy_name_map).fillna(cb_data["strategy_code"])
)
print(cb_data["strategy"].unique())
# Out:
# ['PFLO:HBLE' 'PFLO:NDC_25' 'PFLO:NDC_25_SCOE_ELEC' 'NDC_25_UNCONDITIONAL'
#  'PFLO:NDC_25_UNCONDITIONAL_CE']

# %%
# --- Strategy ID mapping based on strategy_code ---
def map_strategy_id(code: str):
    if code == "BASE":
        return 0
    if code == "PFLO:HBLE":
        return 6004
    if code == "PFLO:NDC_25":
        return 6009
    if code == "PFLO:NDC_25_SCOE_ELEC":
        return 6010
    if code == "PFLO:NDC_25_UNCONDITIONAL":
        return 6011
    if code == "PFLO:NDC_25_UNCONDITIONAL_CE":
        return 6012
    return code  # keep original if not matched

cb_data["strategy_id"] = cb_data["strategy_code"].astype(str).map(map_strategy_id)

# %%
ssp_data.primary_id.unique()
# Out:
# array([     0, 700070, 750075, 760076, 770077, 780078])

# %%
def map_primary_id(code: str):
    if code == "BASE":
        return 0
    if code == "PFLO:HBLE":
        return 700070
    if code == "PFLO:NDC_25":
        return 750075,
    if code == "PFLO:NDC_25_SCOE_ELEC":
        return 760076
    if code == "PFLO:NDC_25_UNCONDITIONAL":
        return 770077
    if code == "PFLO:NDC_25_UNCONDITIONAL_CE":
        return 780078
    return code  # keep original if not matched

cb_data["primary_id"] = cb_data["strategy_code"].astype(str).map(map_primary_id)

# %% [markdown]
# **Manual Tunning Ends Here**

# %%
# --- Create ids (variable:strategy_id) ---
cb_data["ids"] = cb_data["variable"].astype(str) + ":" + cb_data["strategy_id"].astype(str)

# %%
cb_data.head()
# Out:
#   strategy_code  future_id  region  time_period   difference_variable  \
# 0     PFLO:HBLE          0  uganda            4  pop_unimproved_rural
# 1     PFLO:HBLE          0  uganda            5  pop_unimproved_rural
# 2     PFLO:HBLE          0  uganda            6  pop_unimproved_rural
# 3     PFLO:HBLE          0  uganda            7  pop_unimproved_rural
# 4     PFLO:HBLE          0  uganda            8  pop_unimproved_rural
#
#    variable_value_baseline  variable_value_pathway  difference_value  \
# 0             1.932346e+07            1.932346e+07               0.0
# 1             1.951974e+07            1.951974e+07               0.0
# 2             1.896047e+07            1.896047e+07               0.0
# 3             1.837001e+07            1.837001e+07               0.0
# 4             1.774752e+07            1.774752e+07               0.0
#
#                                         variable  value name sector  \
# 0  cb:wali:technical_cost:sanitation:unimp_rural    0.0   cb   wali
# 1  cb:wali:technical_cost:sanitation:unimp_rural    0.0   cb   wali
# 2  cb:wali:technical_cost:sanitation:unimp_rural    0.0   cb   wali
# 3  cb:wali:technical_cost:sanitation:unimp_rural    0.0   cb   wali
# 4  cb:wali:technical_cost:sanitation:unimp_rural    0.0   cb   wali
#
#           cb_type      item_1       item_2  Year   strategy  strategy_id  \
# 0  technical_cost  sanitation  unimp_rural  2019  PFLO:HBLE         6004
# 1  technical_cost  sanitation  unimp_rural  2020  PFLO:HBLE         6004
# 2  technical_cost  sanitation  unimp_rural  2021  PFLO:HBLE         6004
# 3  technical_cost  sanitation  unimp_rural  2022  PFLO:HBLE         6004
# 4  technical_cost  sanitation  unimp_rural  2023  PFLO:HBLE         6004
#
#   primary_id                                                ids
# 0     700070  cb:wali:technical_cost:sanitation:unimp_rural:...
# 1     700070  cb:wali:technical_cost:sanitation:unimp_rural:...
# 2     700070  cb:wali:technical_cost:sanitation:unimp_rural:...
# 3     700070  cb:wali:technical_cost:sanitation:unimp_rural:...
# 4     700070  cb:wali:technical_cost:sanitation:unimp_rural:...

# %%
cb_data.strategy.unique()
# Out:
# array(['PFLO:HBLE', 'PFLO:NDC_25', 'PFLO:NDC_25_SCOE_ELEC',
#        'NDC_25_UNCONDITIONAL', 'PFLO:NDC_25_UNCONDITIONAL_CE'],
#       dtype=object)

# %%
cb_data.strategy_code.unique()
# Out:
# array(['PFLO:HBLE', 'PFLO:NDC_25', 'PFLO:NDC_25_SCOE_ELEC',
#        'PFLO:NDC_25_UNCONDITIONAL', 'PFLO:NDC_25_UNCONDITIONAL_CE'],
#       dtype=object)

# %%
# --- Read GDP and merge ---
# Keep only needed columns
gdp = ssp_data.loc[:, ["primary_id", "time_period", "gdp_mmm_usd"]]
gdp.head(100)
# Out:
#     primary_id  time_period  gdp_mmm_usd
# 0            0            4    96.640000
# 1            0            5    99.490000
# 2            0            6   103.010000
# 3            0            7   107.730000
# 4            0            8   113.483902
# ..         ...          ...          ...
# 95      700070           47   885.672553
# 96      700070           48   903.386004
# 97      700070           49   921.453724
# 98      700070           50   939.882799
# 99      700070           51   958.680455
#
# [100 rows x 3 columns]

# %%
gdp[gdp['primary_id']== 760076]
# Out:
#      primary_id  time_period  gdp_mmm_usd
# 156      760076            4    96.640000
# 157      760076            5    99.490000
# 158      760076            6   103.010000
# 159      760076            7   107.730000
# 160      760076            8   113.483902
# 161      760076            9   120.406420
# 162      760076           10   128.353244
# 163      760076           11   137.787207
# 164      760076           12   150.256950
# 165      760076           13   165.012182
# 166      760076           14   182.090943
# 167      760076           15   200.536755
# 168      760076           16   217.217552
# 169      760076           17   235.175966
# 170      760076           18   254.500096
# 171      760076           19   275.283299
# 172      760076           20   297.630005
# 173      760076           21   321.646185
# 174      760076           22   347.444033
# 175      760076           23   375.142250
# 176      760076           24   404.866352
# 177      760076           25   434.618551
# 178      760076           26   464.059057
# 179      760076           27   492.826532
# 180      760076           28   520.544691
# 181      760076           29   546.829850
# 182      760076           30   571.299252
# 183      760076           31   593.579923
# 184      760076           32   615.601738
# 185      760076           33   637.270920
# 186      760076           34   658.492041
# 187      760076           35   679.168691
# 188      760076           36   699.204168
# 189      760076           37   718.502203
# 190      760076           38   736.967709
# 191      760076           39   754.507541
# 192      760076           40   771.031256
# 193      760076           41   786.451881
# 194      760076           42   802.180919
# 195      760076           43   818.224537
# 196      760076           44   834.589028
# 197      760076           45   851.280808
# 198      760076           46   868.306425
# 199      760076           47   885.672553
# 200      760076           48   903.386004
# 201      760076           49   921.453724
# 202      760076           50   939.882799
# 203      760076           51   958.680455
# 204      760076           52   977.854064
# 205      760076           53   997.411145
# 206      760076           54  1017.359368
# 207      760076           55  1037.706555

# %%
# Merge cb_data with gdp on primary_id and time_period
cb_data = cb_data.merge(gdp, on=["primary_id", "time_period"], how="left")
cb_data
# Out:
#                       strategy_code  future_id  region  time_period  \
# 0                         PFLO:HBLE          0  uganda            4
# 1                         PFLO:HBLE          0  uganda            5
# 2                         PFLO:HBLE          0  uganda            6
# 3                         PFLO:HBLE          0  uganda            7
# 4                         PFLO:HBLE          0  uganda            8
# ...                             ...        ...     ...          ...
# 56959  PFLO:NDC_25_UNCONDITIONAL_CE          0  uganda           51
# 56960  PFLO:NDC_25_UNCONDITIONAL_CE          0  uganda           52
# 56961  PFLO:NDC_25_UNCONDITIONAL_CE          0  uganda           53
# 56962  PFLO:NDC_25_UNCONDITIONAL_CE          0  uganda           54
# 56963  PFLO:NDC_25_UNCONDITIONAL_CE          0  uganda           55
#
#                                    difference_variable  \
# 0                                 pop_unimproved_rural
# 1                                 pop_unimproved_rural
# 2                                 pop_unimproved_rural
# 3                                 pop_unimproved_rural
# 4                                 pop_unimproved_rural
# ...                                                ...
# 56959  frac_scoe_heat_energy_residential_solid_biomass
# 56960  frac_scoe_heat_energy_residential_solid_biomass
# 56961  frac_scoe_heat_energy_residential_solid_biomass
# 56962  frac_scoe_heat_energy_residential_solid_biomass
# 56963  frac_scoe_heat_energy_residential_solid_biomass
#
#        variable_value_baseline  variable_value_pathway  difference_value  \
# 0                 1.932346e+07            1.932346e+07               0.0
# 1                 1.951974e+07            1.951974e+07               0.0
# 2                 1.896047e+07            1.896047e+07               0.0
# 3                 1.837001e+07            1.837001e+07               0.0
# 4                 1.774752e+07            1.774752e+07               0.0
# ...                        ...                     ...               ...
# 56959                      NaN                     NaN               NaN
# 56960                      NaN                     NaN               NaN
# 56961                      NaN                     NaN               NaN
# 56962                      NaN                     NaN               NaN
# 56963                      NaN                     NaN               NaN
#
#                                             variable  value  ... sector  \
# 0      cb:wali:technical_cost:sanitation:unimp_rural    0.0  ...   wali
# 1      cb:wali:technical_cost:sanitation:unimp_rural    0.0  ...   wali
# 2      cb:wali:technical_cost:sanitation:unimp_rural    0.0  ...   wali
# 3      cb:wali:technical_cost:sanitation:unimp_rural    0.0  ...   wali
# 4      cb:wali:technical_cost:sanitation:unimp_rural    0.0  ...   wali
# ...                                              ...    ...  ...    ...
# 56959                   cb:scoe:indoor_air_pollution    0.0  ...   scoe
# 56960                   cb:scoe:indoor_air_pollution    0.0  ...   scoe
# 56961                   cb:scoe:indoor_air_pollution    0.0  ...   scoe
# 56962                   cb:scoe:indoor_air_pollution    0.0  ...   scoe
# 56963                   cb:scoe:indoor_air_pollution    0.0  ...   scoe
#
#                     cb_type      item_1       item_2  Year  \
# 0            technical_cost  sanitation  unimp_rural  2019
# 1            technical_cost  sanitation  unimp_rural  2020
# 2            technical_cost  sanitation  unimp_rural  2021
# 3            technical_cost  sanitation  unimp_rural  2022
# 4            technical_cost  sanitation  unimp_rural  2023
# ...                     ...         ...          ...   ...
# 56959  indoor_air_pollution        None         None  2066
# 56960  indoor_air_pollution        None         None  2067
# 56961  indoor_air_pollution        None         None  2068
# 56962  indoor_air_pollution        None         None  2069
# 56963  indoor_air_pollution        None         None  2070
#
#                            strategy strategy_id  primary_id  \
# 0                         PFLO:HBLE        6004      700070
# 1                         PFLO:HBLE        6004      700070
# 2                         PFLO:HBLE        6004      700070
# 3                         PFLO:HBLE        6004      700070
# 4                         PFLO:HBLE        6004      700070
# ...                             ...         ...         ...
# 56959  PFLO:NDC_25_UNCONDITIONAL_CE        6012      780078
# 56960  PFLO:NDC_25_UNCONDITIONAL_CE        6012      780078
# 56961  PFLO:NDC_25_UNCONDITIONAL_CE        6012      780078
# 56962  PFLO:NDC_25_UNCONDITIONAL_CE        6012      780078
# 56963  PFLO:NDC_25_UNCONDITIONAL_CE        6012      780078
#
#                                                      ids  gdp_mmm_usd
# 0      cb:wali:technical_cost:sanitation:unimp_rural:...    96.640000
# 1      cb:wali:technical_cost:sanitation:unimp_rural:...    99.490000
# 2      cb:wali:technical_cost:sanitation:unimp_rural:...   103.010000
# 3      cb:wali:technical_cost:sanitation:unimp_rural:...   107.730000
# 4      cb:wali:technical_cost:sanitation:unimp_rural:...   113.483902
# ...                                                  ...          ...
# 56959                  cb:scoe:indoor_air_pollution:6012   958.680455
# 56960                  cb:scoe:indoor_air_pollution:6012   977.854064
# 56961                  cb:scoe:indoor_air_pollution:6012   997.411145
# 56962                  cb:scoe:indoor_air_pollution:6012  1017.359368
# 56963                  cb:scoe:indoor_air_pollution:6012  1037.706555
#
# [56964 rows x 21 columns]

# %%
96.640000/35.35
# Out:
# 2.7338048090523337

# %%
cb_data[['time_period','gdp_mmm_usd']]

# 2019: 96.640000 #PPP
# 2019: 35.35 #USD
# 2.7
# https://data.worldbank.org/indicator/NY.GDP.MKTP.CD?locations=UG
# Out:
#        time_period  gdp_mmm_usd
# 0                4    96.640000
# 1                5    99.490000
# 2                6   103.010000
# 3                7   107.730000
# 4                8   113.483902
# ...            ...          ...
# 56959           51   958.680455
# 56960           52   977.854064
# 56961           53   997.411145
# 56962           54  1017.359368
# 56963           55  1037.706555
#
# [56964 rows x 2 columns]

# %%
cb_data.isna().sum()
# Out:
# strategy_code                  0
# future_id                      0
# region                         0
# time_period                    0
# difference_variable            0
# variable_value_baseline      260
# variable_value_pathway       416
# difference_value             260
# variable                       0
# value                          0
# name                           0
# sector                         0
# cb_type                        0
# item_1                       260
# item_2                      4068
# Year                           0
# strategy                       0
# strategy_id                    0
# primary_id                     0
# ids                            0
# gdp_mmm_usd                12120
# dtype: int64

# %%
# Save the results
cb_data.to_csv(os.path.join(CB_OUTPUT, "cba_data_air_pollution.csv"), index = False)

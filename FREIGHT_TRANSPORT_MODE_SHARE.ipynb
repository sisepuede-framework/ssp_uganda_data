# %% [markdown]
# ## Source
#
# This variables are created using the transports demand CSVs created in `FREIGHT_TRANSPORT_DEMAND.ipynb`

# %%
import numpy as np
import pandas as pd
import os
from utils.utils import EDAUtils, TransportUtils

# %%
# %load_ext autoreload
# %autoreload 2

# %%
edau = EDAUtils()
tu = TransportUtils()

# %%
# Set up paths
CURRENT_DIR_PATH = os.getcwd()
OUTPUT_DATA_DIR_PATH = os.path.join(CURRENT_DIR_PATH, "output_data")
INPUT_DATA_DIR_PATH = os.path.join(CURRENT_DIR_PATH, "input_data")

# %%
# Load passenger data
freight_demand_df = pd.read_csv(os.path.join(OUTPUT_DATA_DIR_PATH, "deminit_trde_freight_mt_km.csv"))
freight_demand_df.head()
# Out:
#    year  deminit_trde_freight_mt_km
# 0  2015                42403.968375
# 1  2016                44432.147553
# 2  2017                45827.191432
# 3  2018                48713.859151
# 4  2019                51852.707879

# %%
# aviation``|``rail_freight``|``road_heavy_freight``|``water_borne
freight_mode_shares = {
    "aviation": 0.0020,
    "rail_freight": 0.0015,
    "road_heavy_freight": 0.8698,
    "water_borne": 0.1267
}

# %%
freight_mode_share_df = freight_demand_df.copy()

# %%
for key, value in freight_mode_shares.items():
    var_name = f"frac_trns_mtkm_dem_freight_{key}"
    freight_mode_share_df[var_name] =  freight_demand_df["deminit_trde_freight_mt_km"] * value

# %%
freight_mode_share_df.head()
# Out:
#    year  deminit_trde_freight_mt_km  frac_trns_mtkm_dem_freight_aviation  \
# 0  2015                42403.968375                            84.807937
# 1  2016                44432.147553                            88.864295
# 2  2017                45827.191432                            91.654383
# 3  2018                48713.859151                            97.427718
# 4  2019                51852.707879                           103.705416
#
#    frac_trns_mtkm_dem_freight_rail_freight  \
# 0                                63.605953
# 1                                66.648221
# 2                                68.740787
# 3                                73.070789
# 4                                77.779062
#
#    frac_trns_mtkm_dem_freight_road_heavy_freight  \
# 0                                   36882.971692
# 1                                   38647.081941
# 2                                   39860.491108
# 3                                   42371.314690
# 4                                   45101.485314
#
#    frac_trns_mtkm_dem_freight_water_borne
# 0                             5372.582793
# 1                             5629.553095
# 2                             5806.305154
# 3                             6172.045954
# 4                             6569.738088

# %%
freight_mode_share_df.drop(columns=["deminit_trde_freight_mt_km"], inplace=True)
freight_mode_share_df.head()
# Out:
#    year  frac_trns_mtkm_dem_freight_aviation  \
# 0  2015                            84.807937
# 1  2016                            88.864295
# 2  2017                            91.654383
# 3  2018                            97.427718
# 4  2019                           103.705416
#
#    frac_trns_mtkm_dem_freight_rail_freight  \
# 0                                63.605953
# 1                                66.648221
# 2                                68.740787
# 3                                73.070789
# 4                                77.779062
#
#    frac_trns_mtkm_dem_freight_road_heavy_freight  \
# 0                                   36882.971692
# 1                                   38647.081941
# 2                                   39860.491108
# 3                                   42371.314690
# 4                                   45101.485314
#
#    frac_trns_mtkm_dem_freight_water_borne
# 0                             5372.582793
# 1                             5629.553095
# 2                             5806.305154
# 3                             6172.045954
# 4                             6569.738088

# %%
freight_mode_share_df.tail()
# Out:
#     year  frac_trns_mtkm_dem_freight_aviation  \
# 82  2096                           103.705416
# 83  2097                           103.705416
# 84  2098                           103.705416
# 85  2099                           103.705416
# 86  2100                           103.705416
#
#     frac_trns_mtkm_dem_freight_rail_freight  \
# 82                                77.779062
# 83                                77.779062
# 84                                77.779062
# 85                                77.779062
# 86                                77.779062
#
#     frac_trns_mtkm_dem_freight_road_heavy_freight  \
# 82                                   45101.485314
# 83                                   45101.485314
# 84                                   45101.485314
# 85                                   45101.485314
# 86                                   45101.485314
#
#     frac_trns_mtkm_dem_freight_water_borne
# 82                             6569.738088
# 83                             6569.738088
# 84                             6569.738088
# 85                             6569.738088
# 86                             6569.738088

# %%
freight_mode_share_df.to_csv(os.path.join(OUTPUT_DATA_DIR_PATH, "frac_trns_mtkm_dem_freight.csv"), index=False)
